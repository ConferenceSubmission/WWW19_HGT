# %%
import sys
sys.path.append('../')
from utils import *
from model import *
from collections import defaultdict
from gensim.parsing.preprocessing import strip_punctuation
from gensim.models import Word2Vec

# %%
data_dir = '/datadrive/data_cs/'
batch_size = 128
batch_num  = 128
epoch_num  = 200

device = torch.device("cuda:1")
graph = dill.load(open(data_dir + 'graph.pk', 'rb'))

# %%
train_range = {t: True for t in graph.times if t != None and t < 2015}
valid_range = {t: True for t in graph.times if t != None and t >= 2015  and t <= 2016}
test_range  = {t: True for t in graph.times if t != None and t > 2016}

# %%
class GNN(nn.Module):
    def __init__(self, in_dim, n_hid, num_types, num_relations, n_heads, n_layers, dropout = 0.3):
        super(GNN, self).__init__()
        self.gcs = nn.ModuleList()
        self.num_types = num_types
        self.in_dim    = in_dim
        self.n_hid     = n_hid
        self.aggregat_ws   = nn.ModuleList()
        self.drop          = nn.Dropout(dropout)
        for t in range(num_types):
            self.aggregat_ws.append(nn.Linear(in_dim, n_hid))
        for l in range(n_layers):
            self.gcs.append(RAGCNConv(n_hid, n_hid, num_types, num_relations, n_heads, dropout))
    def set_device(self, device):
        self.device = device
        for gc in self.gcs:
            gc.device = device
    def forward(self, node_feature, node_type, edge_time, edge_index, edge_type):
        res = torch.zeros(node_feature.size(0), self.n_hid).to(node_feature.device)
        for t_id in range(self.num_types):
            aggregat_w = self.aggregat_ws[t_id]
            idx = (node_type == t_id)
            if idx.sum() == 0:
                continue
            res[idx] = torch.tanh(aggregat_w(node_feature[idx]))
        meta_xs = self.drop(res)
        del res
        for gc in self.gcs:
            meta_xs = gc(meta_xs, node_type, edge_index, edge_type, edge_time)
        return meta_xs

# %%
def gen_sample(seed, t_range, sampled_depth = 5, sampled_number = 100, batch_size = batch_size):
    np.random.seed(seed)
    feature, _time, edge_list, _, texts = sample_subgraph(graph, t_range, inp = None, \
                        sampled_depth = sampled_depth, sampled_number = sampled_number)  
    paper_ids = np.random.choice(len(_time['paper']), batch_size, replace = False)
    
    for target_type in edge_list:
        tes = edge_list[target_type]['paper']
        for relation_type in tes:
            reml = []
            for target_ser, source_ser in tes[relation_type]:
                if source_ser not in paper_ids:
                    reml += [[target_ser, source_ser]]
            edge_list[target_type]['paper'][relation_type] = reml
    return to_torch(feature, _time, edge_list, graph), paper_ids, texts[paper_ids]

def prepare_data(pool, process_ids):
    jobs = []
    for process_id in process_ids[:-1]:
        p = pool.apply_async(gen_sample, args=(np.random.randint(2**32 - 1), train_range))
        jobs.append(p)
#     p = pool.apply_async(gen_sample, args=(np.random.randint(2**32 - 1), valid_range))
#     jobs.append(p)
#     p = pool.apply_async(gen_sample, args=(np.random.randint(2**32 - 1), valid_range))
#     jobs.append(p)
    return jobs

# %%
class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""
    def __init__(self, n_word, ninp, nhid, nlayers, dropout=0.3):
        super(RNNModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.rnn = nn.LSTM(nhid, nhid, nlayers)
        self.encoder = nn.Embedding(n_word, nhid)
        self.decoder = nn.Linear(nhid, n_word)
        self.decoder.weight = self.encoder.weight
        self.adp     = nn.Linear(ninp + nhid, nhid)
        self.encoder.weight.require_grad = False
    def forward(self, inp, hidden = None):
        emb = self.drop(self.encoder(inp))
        if hidden is not None:
            emb = torch.cat((emb, hidden), dim=-1)
            emb = F.elu(self.adp(emb))
        output, _ = self.rnn(self.drop(emb))
        decoded = self.decoder(self.drop(output))
        return decoded
    def from_w2v(self, w2v):
        initrange = 0.1
        self.encoder.weight.data = w2v

# %%
edge_dict = {e[2]: i for i, e in enumerate(graph.get_meta_graph())}

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    """Container module with an encoder, a recurrent or transformer module, and a decoder."""

    def __init__(self, n_word, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        try:
            from torch.nn import TransformerEncoder, TransformerEncoderLayer
        except:
            raise ImportError('TransformerEncoder module does not exist in PyTorch 1.1 or lower.')
        self.model_type = 'Transformer'
        encoder_layers = TransformerEncoderLayer(nhid, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.adp     = nn.Linear(ninp + nhid, nhid)
        self.encoder = nn.Embedding(n_word, ninp)
        self.pos_encoder = PositionalEncoding(nhid, dropout)
        self.decoder = nn.Linear(nhid, n_word)
        self.encoder.weight.require_grad = False
        self.init_weights()
        self.drop = nn.Dropout(0.3)
        self.nhid = nhid
    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask
    def from_w2v(self, w2v):
        initrange = 0.1
        self.encoder.weight.data = w2v
    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)
        
    def forward(self, src, hidden = None):
        device = src.device
        mask = self._generate_square_subsequent_mask(len(src)).to(device)

        emb = self.encoder(src)
        if hidden is not None:
            emb = self.drop(torch.cat((emb, hidden), dim=-1))
            emb = F.elu(self.adp(emb))
        emb = self.pos_encoder(emb * math.sqrt(self.nhid))
        output = self.transformer_encoder(emb, mask)
        return self.decoder(output)

# %%
types = graph.get_types()
gnn = GNN(in_dim = len(graph.node_feature['paper']['emb'][0]) + 401, n_hid = 256, num_types = len(types), \
          num_relations = len(graph.get_meta_graph()) + 1, n_heads = 8, n_layers = 4).to(device)

w2v_model = Word2Vec.load(data_dir + "word2vec.model")
n_tokens = len(w2v_model.wv.vocab)
rnn = TransformerModel(n_word = n_tokens, ninp = gnn.n_hid, nhead = 4,\
               nhid = w2v_model.vector_size, nlayers = 2).to(device)
rnn.from_w2v(torch.FloatTensor(w2v_model.wv.vectors).to(device))
optimizer = torch.optim.AdamW(list(gnn.parameters()) + list(rnn.parameters()))
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 1000, eta_min=1e-6)
# Out:
# /home/ziniu/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# types = graph.get_types()
# gnn = GNN(in_dim = len(graph.node_feature['paper']['emb'][0]) + 401, n_hid = 256, num_types = len(types), \
#           num_relations = len(graph.get_meta_graph()) + 1, n_heads = 8, n_layers = 3).to(device)

# w2v_model = Word2Vec.load(data_dir + "word2vec.model")
# n_tokens = len(w2v_model.wv.vocab)
# rnn = RNNModel(n_word = n_tokens, ninp = gnn.n_hid, \
#                nhid = w2v_model.vector_size, nlayers = 2).to(device)
# rnn.from_w2v(torch.FloatTensor(w2v_model.wv.vectors).to(device))
# optimizer = torch.optim.AdamW(list(gnn.parameters()) + list(rnn.parameters()))
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 1000, eta_min=1e-6)

# %%
def parse_text(texts, w2v_model, device):
    idxs = []
    pad  = w2v_model.wv.vocab['<eos>'].index
    for text in texts:
        idx = []
        for word in ['<bos>'] + strip_punctuation(text.lower()).split() + ['<eos>']:
            if word in w2v_model.wv.vocab:
                idx += [w2v_model.wv.vocab[word].index]
        idxs += [idx]
    mxl = np.max([len(s) for s in idxs]) + 1
    inp_idxs = []
    out_idxs = []
    masks    = []
    lens     = []
    for i, idx in enumerate(idxs):
        inp_idxs += [idx + [pad for _ in range(mxl - len(idx) - 1)]]
        out_idxs += [idx[1:] + [pad for _ in range(mxl - len(idx))]]
        masks    += [[1 for _ in range(len(idx))] + [0 for _ in range(mxl - len(idx) - 1)]]
        lens     += [len(idx)]
    return torch.LongTensor(inp_idxs).transpose(0, 1).to(device), \
           torch.LongTensor(out_idxs).transpose(0, 1).to(device), torch.BoolTensor(masks).transpose(0, 1).to(device), lens

# %%
def sample_subgraph(graph, time_range, sampled_depth = 2, sampled_number = 8, inp = None):
    '''
        Sample Sub-Graph based on the connection of other nodes with currently sampled nodes
        We maintain budgets for each node type, indexed by <node_id, time>.
        Currently sampled nodes are stored in layer_data.
        After nodes are sampled, we construct the sampled adjacancy matrix.
    '''
    layer_data  = defaultdict( #target_type
                        lambda: {} # {target_id: [ser, time]}
                    )
    budget     = defaultdict( #source_type
                                    lambda: defaultdict(  #source_id
                                        lambda: [0., 0] #[sampled_score, time]
                            ))
    new_layer_adj  = defaultdict( #target_type
                                    lambda: defaultdict(  #source_type
                                        lambda: defaultdict(  #relation_type
                                            lambda: [] #[target_id, source_id]
                                )))
    ban   = defaultdict( #target_type
                        lambda: {} # {target_id}
                    )
    '''
        For each node being sampled, we find out all its neighborhood, 
        adding the degree count of these nodes in the budget.
        Note that there exist some nodes that have many neighborhoods
        (such as fields, venues), for those case, we only consider 
    '''
    def add_budget(te, target_id, target_time, layer_data, budget):
        for source_type in te:
            tes = te[source_type]
            for relation_type in tes:
                if relation_type == 'self' or target_id not in tes[relation_type]:
                    continue
                adl = tes[relation_type][target_id]
                if len(adl) < sampled_number:
                    sampled_ids = list(adl.keys())
                else:
                    sampled_ids = np.random.choice(list(adl.keys()), sampled_number, replace = False)
                for source_id in sampled_ids:
                    source_time = adl[source_id]
                    if source_time == None:
                        source_time = target_time
                    if source_time not in time_range or source_id in layer_data[source_type]:
                        continue
                    budget[source_type][source_id][0] += 1. / len(sampled_ids)
                    budget[source_type][source_id][1] = source_time
    '''
        If inp == None: we sample some paper as initial nodes;
        else:           we are dealing with a specific supervised task (e.g. author disambiguation),
                        where some node pairs are given as output.
    '''
    
    if inp == None:
        _time = np.random.choice(list(time_range.keys()))
        res = graph.node_feature['paper'][graph.node_feature['paper']['time'] == _time]
        sampn = min(len(res), sampled_number)
        rand_paper_ids  = np.random.choice(list(res.index), sampn, replace = False)
        '''
            First adding the sampled nodes then updating budget.
        '''
        for _id in rand_paper_ids:
            layer_data['paper'][_id] = [len(layer_data['paper']), _time]
        for _id in rand_paper_ids:
            add_budget(graph.edge_list['paper'], _id, _time, layer_data, budget)
    else:
        '''
            First adding the sampled nodes then updating budget.
        '''
        for _type in inp:
            for _id, _time in inp[_type]:
                layer_data[_type][_id] = [len(layer_data[_type]), _time]
        for _type in inp:
            te = graph.edge_list[_type]
            for _id, _time in inp[_type]:
                add_budget(te, _id, _time, layer_data, budget)
    '''
        We recursively expand the sampled graph by sampled_depth.
        Each time we sample a fixed number of nodes for each budget,
        based on the accumulated degree.
    '''
    for layer in range(sampled_depth):
        sts = list(budget.keys())
        for source_type in sts:
            te = graph.edge_list[source_type]
            keys  = np.array(list(budget[source_type].keys()))
            if sampled_number > len(keys):
                '''
                    Directly sample all the nodes
                '''
                sampled_ids = np.arange(len(keys))
            else:
                '''
                    Sample based on accumulated degree
                '''
                score = np.array(list(budget[source_type].values()))[:,0] ** 2
                score = score / np.sum(score)
                sampled_ids = np.random.choice(len(score), sampled_number, p = score, replace = False) 
            sampled_keys = keys[sampled_ids]
            '''
                First adding the sampled nodes then updating budget.
            '''
            for k in sampled_keys:
                layer_data[source_type][k] = [len(layer_data[source_type]), budget[source_type][k][1]]
            for k in sampled_keys:
                add_budget(te, k, budget[source_type][k][1], layer_data, budget)
                budget[source_type].pop(k)   
    '''
        Prepare feature, time and adjacency matrix for the sampled graph
    '''
    feature = {}
    times   = {}
    indxs   = {}
    texts   = []
    for _type in layer_data:
        if len(layer_data[_type]) == 0:
            continue
        idxs  = np.array(list(layer_data[_type].keys()))
        tims  = np.array(list(layer_data[_type].values()))[:,0]
        
        if 'node_emb' in graph.node_feature[_type]:
            feature[_type] = np.array(list(graph.node_feature[_type].loc[idxs, 'node_emb']), dtype=np.float)
        else:
            feature[_type] = np.zeros([len(idxs), 400])
        feature[_type] = np.concatenate((feature[_type], list(graph.node_feature[_type].loc[idxs, 'emb']),\
            np.log10(np.array(list(graph.node_feature[_type].loc[idxs, 'citation'])).reshape(-1, 1) + 0.01)), axis=1)
        
        times[_type]   = tims
        indxs[_type]   = idxs
        
        if _type == 'paper':
            texts = np.array(list(graph.node_feature[_type].loc[idxs, 'title']), dtype=np.str)
    edge_list = defaultdict( #target_type
                        lambda: defaultdict(  #source_type
                            lambda: defaultdict(  #relation_type
                                lambda: [] # [target_id, source_id] 
                                    )))
    for _type in layer_data:
        for _key in layer_data[_type]:
            _ser = layer_data[_type][_key][0]
            edge_list[_type][_type]['self'] += [[_ser, _ser]]
    '''
        Reconstruct sampled adjacancy matrix by checking whether each
        link exist in the original graph
    '''
    for target_type in graph.edge_list:
        te = graph.edge_list[target_type]
        for source_type in te:
            tes = te[source_type]
            for relation_type in tes:
                tesr = tes[relation_type]
                for target_key in layer_data[target_type]:
                    target_ser = layer_data[target_type][target_key][0]
                    if target_key not in tesr:
                        continue
                    tesrt = tesr[target_key]
                    for source_key in layer_data[source_type]:
                        source_ser = layer_data[source_type][source_key][0]
                        '''
                            Check whether each link (target_id, source_id) exist in original adjacancy matrix
                        '''
                        if source_key in tesrt:
                            edge_list[target_type][source_type][relation_type] += [[target_ser, source_ser]]
    return feature, times, edge_list, indxs, texts

# %%
def to_torch(feature, time, edge_list, graph):
    '''
        Transform a sampled sub-graph into pytorch Tensor
        node_dict: {node_type: <node_number, node_type_ID>} node_number is used to trace back the nodes in original graph.
        edge_dict: {edge_type: edge_type_ID}
    '''
    node_dict = {}
    node_feature = []
    node_type    = []
    node_time    = []
    edge_index   = []
    edge_type    = []
    edge_time    = []
    
    node_num = 0
    types = graph.get_types()
    for t in types:
        node_dict[t] = [node_num, len(node_dict)]
        node_num     += len(feature[t])
        
        
    if 'fake_paper' in feature:
        node_dict['fake_paper'] = [node_num, node_dict['paper'][1]]
        node_num     += len(feature['fake_paper'])
        types += ['fake_paper']
    for t in types:
        node_feature += list(feature[t])
        node_time    += list(time[t])
        node_type    += [node_dict[t][1] for _ in range(len(feature[t]))]
        
    edge_dict = {e[2]: i for i, e in enumerate(graph.get_meta_graph())}
    edge_dict['self'] = len(edge_dict)

    
    
    for target_type in edge_list:
        for source_type in edge_list[target_type]:
            for relation_type in edge_list[target_type][source_type]:
                for ti, si in edge_list[target_type][source_type][relation_type]:
                    tid, sid = ti + node_dict[target_type][0], si + node_dict[source_type][0]
                    edge_index += [[tid, sid]]
                    edge_type  += [edge_dict[relation_type]]   
                    '''
                        Our time ranges from 1900 - 2020, largest span is 120.
                    '''
                    edge_time  += [node_time[tid] - node_time[sid] + 120]
    node_feature = torch.FloatTensor(node_feature)
    node_type    = torch.LongTensor(node_type)
    edge_time    = torch.LongTensor(edge_time)
    edge_index   = torch.LongTensor(edge_index).t()
    edge_type    = torch.LongTensor(edge_type)
    return node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict

# %%
stats = []
pool = mp.Pool(1)
process_ids = np.arange(batch_num // 8)
st = time.time()
jobs = prepare_data(pool, process_ids)
train_step = 1500
best_val   = 100000
criterion = nn.CrossEntropyLoss(reduction = 'none')
# Out:
# 0 0 0 paper paper
# 1 1 1 paper paper
# 2 2 2 paper paper
# 3 3 3 paper paper
# 4 4 4 paper paper
# 5 5 5 paper paper
# 6 6 6 paper paper
# 7 7 7 paper paper
# 8 8 8 paper paper
# 9 9 9 paper paper
# 10 10 10 paper paper
# 11 11 11 paper paper
# 12 12 12 paper paper
# 13 13 13 paper paper
# 14 14 14 paper paper
# 15 15 15 paper paper
# 16 16 16 paper paper
# 17 17 17 paper paper
# 18 18 18 paper paper
# 19 19 19 paper paper
# 20 20 20 paper paper
# 21 21 21 paper paper
# 22 22 22 paper paper
# 23 23 23 paper paper
# 24 24 24 paper paper
# 25 25 25 paper paper
# 26 26 26 paper paper
# 27 27 27 paper paper
# 28 28 28 paper paper
# 29 29 29 paper paper
# 30 30 30 paper paper
# 31 31 31 paper paper
# 32 32 32 paper paper
# 33 33 33 paper paper
# 34 34 34 paper paper
# 35 35 35 paper paper
# 36 36 36 paper paper
# 37 37 37 paper paper
# 38 38 38 paper paper
# 39 39 39 paper paper
# 40 40 40 paper paper
# 41 41 41 paper paper
# 42 42 42 paper paper
# 43 43 43 paper paper
# 44 44 44 paper paper
# 45 45 45 paper paper
# 46 46 46 paper paper
# 47 47 47 paper paper
# 48 48 48 paper paper
# 49 49 49 paper paper
# 50 50 50 paper paper
# 51 51 51 paper paper
# 52 52 52 paper paper
# 53 53 53 paper paper
# 54 54 54 paper paper
# 55 55 55 paper paper
# 56 56 56 paper paper
# 57 57 57 paper paper
# 58 58 58 paper paper
# 59 59 59 paper paper
# 60 60 60 paper paper
# 61 61 61 paper paper
# 62 62 62 paper paper
# 63 63 63 paper paper
# 64 64 64 paper paper
# 65 65 65 paper paper
# 66 66 66 paper paper
# 67 67 67 paper paper
# 68 68 68 paper paper
# 69 69 69 paper paper
# 70 70 70 paper paper
# 71 71 71 paper paper
# 72 72 72 paper paper
# 73 73 73 paper paper
# 74 74 74 paper paper
# 75 75 75 paper paper
# 76 76 76 paper paper
# 77 77 77 paper paper
# 82 82 82 paper paper
# 78 78 78 paper paper
# 79 79 79 paper paper
# 80 80 80 paper paper
# 81 81 81 paper paper
# 83 83 83 paper paper
# 84 84 84 paper paper
# 85 85 85 paper paper
# 86 86 86 paper paper
# 87 87 87 paper paper
# 88 88 88 paper paper
# 89 89 89 paper paper
# 90 90 90 paper paper
# 91 91 91 paper paper
# 92 92 92 paper paper
# 93 93 93 paper paper
# 94 94 94 paper paper
# 95 95 95 paper paper
# 96 96 96 paper paper
# 97 97 97 paper paper
# 98 98 98 paper paper
# 99 99 99 paper paper
# 100 100 100 paper paper
# 101 101 101 paper paper
# 102 102 102 paper paper
# 103 103 103 paper paper
# 104 104 104 paper paper
# 105 105 105 paper paper
# 106 106 106 paper paper
# 107 107 107 paper paper
# 108 108 108 paper paper
# 109 109 109 paper paper
# 110 110 110 paper paper
# 111 111 111 paper paper
# 112 112 112 paper paper
# 113 113 113 paper paper
# 114 114 114 paper paper
# 115 115 115 paper paper
# 116 116 116 paper paper
# 117 117 117 paper paper
# 118 118 118 paper paper
# 119 119 119 paper paper
# 120 120 120 paper paper
# 121 121 121 paper paper
# 122 122 122 paper paper
# 123 123 123 paper paper
# 124 124 124 paper paper
# 125 125 125 paper paper
# 126 126 126 paper paper
# 127 127 127 paper paper
# 128 128 128 paper paper
# 129 129 129 paper paper
# 130 130 130 paper paper
# 131 131 131 paper paper
# 132 132 132 paper paper
# 133 133 133 paper paper
# 134 134 134 paper paper
# 135 135 135 paper paper
# 136 136 136 paper paper
# 137 137 137 paper paper
# 138 138 138 paper paper
# 139 139 139 paper paper
# 140 140 140 paper paper
# 141 141 141 paper paper
# 142 142 142 paper paper
# 143 143 143 paper paper
# 144 144 144 paper paper
# 145 145 145 paper paper
# 146 146 146 paper paper
# 147 147 147 paper paper
# 148 148 148 paper paper
# 149 149 149 paper paper
# 150 150 150 paper paper
# 151 151 151 paper paper
# 152 152 152 paper paper
# 153 153 153 paper paper
# 154 154 154 paper paper
# 155 155 155 paper paper
# 156 156 156 paper paper
# 157 157 157 paper paper
# 158 158 158 paper paper
# 159 159 159 paper paper
# 160 160 160 paper paper
# 161 161 161 paper paper
# 162 162 162 paper paper
# 163 163 163 paper paper
# 164 164 164 paper paper
# 165 165 165 paper paper
# 166 166 166 paper paper
# 167 167 167 paper paper
# 168 168 168 paper paper
# 169 169 169 paper paper
# 170 170 170 paper paper
# 171 171 171 paper paper
# 172 172 172 paper paper
# 173 173 173 paper paper
# 174 174 174 paper paper
# 175 175 175 paper paper
# 176 176 176 paper paper
# 177 177 177 paper paper
# 178 178 178 paper paper
# 179 179 179 paper paper
# 180 180 180 paper paper
# 181 181 181 paper paper
# 182 182 182 paper paper
# 183 183 183 paper paper
# 184 184 184 paper paper
# 185 185 185 paper paper
# 186 186 186 paper paper
# 187 187 187 paper paper
# 188 188 188 paper paper
# 189 189 189 paper paper
# 190 190 190 paper paper
# 191 191 191 paper paper
# 192 192 192 paper paper
# 193 193 193 paper paper
# 194 194 194 paper paper
# 195 195 195 paper paper
# 196 196 196 paper paper
# 197 197 197 paper paper
# 198 198 198 paper paper
# 199 199 199 paper paper
# 200 200 200 paper paper
# 201 201 201 paper paper
# 202 202 202 paper paper
# 203 203 203 paper paper
# 204 204 204 paper paper
# 205 205 205 paper paper
# 206 206 206 paper paper
# 207 207 207 paper paper
# 208 208 208 paper paper
# 209 209 209 paper paper
# 210 210 210 paper paper
# 211 211 211 paper paper
# 212 212 212 paper paper
# 213 213 213 paper paper
# 214 214 214 paper paper
# 215 215 215 paper paper
# 216 216 216 paper paper
# 217 217 217 paper paper
# 218 218 218 paper paper
# 219 219 219 paper paper
# 220 220 220 paper paper
# 221 221 221 paper paper
# 222 222 222 paper paper
# 223 223 223 paper paper
# 224 224 224 paper paper
# 225 225 225 paper paper
# 226 226 226 paper paper
# 227 227 227 paper paper
# 228 228 228 paper paper
# 229 229 229 paper paper
# 230 230 230 paper paper
# 231 231 231 paper paper
# 232 232 232 paper paper
# 233 233 233 paper paper
# 234 234 234 paper paper
# 235 235 235 paper paper
# 236 236 236 paper paper
# 237 237 237 paper paper
# 238 238 238 paper paper
# 239 239 239 paper paper
# 240 240 240 paper paper
# 241 241 241 paper paper
# 242 242 242 paper paper
# 243 243 243 paper paper
# 244 244 244 paper paper
# 245 245 245 paper paper
# 246 246 246 paper paper
# 247 247 247 paper paper
# 248 248 248 paper paper
# 249 249 249 paper paper
# 250 250 250 paper paper
# 251 251 251 paper paper
# 252 252 252 paper paper
# 253 253 253 paper paper
# 254 254 254 paper paper
# 255 255 255 paper paper
# 256 256 256 paper paper
# 257 257 257 paper paper
# 258 258 258 paper paper
# 259 259 259 paper paper
# 260 260 260 paper paper
# 261 261 261 paper paper
# 262 262 262 paper paper
# 263 263 263 paper paper
# 264 264 264 paper paper
# 265 265 265 paper paper
# 266 266 266 paper paper
# 267 267 267 paper paper
# 268 268 268 paper paper
# 269 269 269 paper paper
# 270 270 270 paper paper
# 271 271 271 paper paper
# 272 272 272 paper paper
# 273 273 273 paper paper
# 274 274 274 paper paper
# 275 275 275 paper paper
# 276 276 276 paper paper
# 277 277 277 paper paper
# 278 278 278 paper paper
# 279 279 279 paper paper
# 280 280 280 paper paper
# 281 281 281 paper paper
# 282 282 282 paper paper
# 283 283 283 paper paper
# 284 284 284 paper paper
# 285 285 285 paper paper
# 286 286 286 paper paper
# 287 287 287 paper paper
# 288 288 288 paper paper
# 289 289 289 paper paper
# 290 290 290 paper paper
# 291 291 291 paper paper
# 292 292 292 paper paper
# 293 293 293 paper paper
# 294 294 294 paper paper
# 295 295 295 paper paper
# 296 296 296 paper paper
# 297 297 297 paper paper
# 298 298 298 paper paper
# 299 299 299 paper paper
# 300 300 300 paper paper
# 301 301 301 paper paper
# 302 302 302 paper paper
# 303 303 303 paper paper
# 304 304 304 paper paper
# 305 305 305 paper paper
# 306 306 306 paper paper
# 307 307 307 paper paper
# 308 308 308 paper paper
# 309 309 309 paper paper
# 310 310 310 paper paper
# 311 311 311 paper paper
# 312 312 312 paper paper
# 313 313 313 paper paper
# 314 314 314 paper paper
# 315 315 315 paper paper
# 316 316 316 paper paper
# 317 317 317 paper paper
# 318 318 318 paper paper
# 319 319 319 paper paper
# 320 320 320 paper paper
# 321 321 321 paper paper
# 322 322 322 paper paper
# 323 323 323 paper paper
# 324 324 324 paper paper
# 325 325 325 paper paper
# 326 326 326 paper paper
# 327 327 327 paper paper
# 328 328 328 paper paper
# 329 329 329 paper paper
# 330 330 330 paper paper
# 331 331 331 paper paper
# 332 332 332 paper paper
# 333 333 333 paper paper
# 334 334 334 paper paper
# 335 335 335 paper paper
# 336 336 336 paper paper
# 337 337 337 paper paper
# 338 338 338 paper paper
# 339 339 339 paper paper
# 340 340 340 paper paper
# 341 341 341 paper paper
# 342 342 342 paper paper
# 343 343 343 paper paper
# 344 344 344 paper paper
# 345 345 345 paper paper
# 346 346 346 paper paper
# 347 347 347 paper paper
# 348 348 348 paper paper
# 349 349 349 paper paper
# 350 350 350 paper paper
# 351 351 351 paper paper
# 352 352 352 paper paper
# 353 353 353 paper paper
# 354 354 354 paper paper
# 355 355 355 paper paper
# 356 356 356 paper paper
# 357 357 357 paper paper
# 358 358 358 paper paper
# 359 359 359 paper paper
# 360 360 360 paper paper
# 361 361 361 paper paper
# 362 362 362 paper paper
# 363 363 363 paper paper
# 364 364 364 paper paper
# 365 365 365 paper paper
# 366 366 366 paper paper
# 367 367 367 paper paper
# 368 368 368 paper paper
# 369 369 369 paper paper
# 370 370 370 paper paper
# 371 371 371 paper paper
# 372 372 372 paper paper
# 373 373 373 paper paper
# 374 374 374 paper paper
# 375 375 375 paper paper
# 376 376 376 paper paper
# 377 377 377 paper paper
# 378 378 378 paper paper
# 379 379 379 paper paper
# 380 380 380 paper paper
# 381 381 381 paper paper
# 382 382 382 paper paper
# 383 383 383 paper paper
# 384 384 384 paper paper
# 385 385 385 paper paper
# 386 386 386 paper paper
# 387 387 387 paper paper
# 388 388 388 paper paper
# 389 389 389 paper paper
# 390 390 390 paper paper
# 171 116 8 paper paper
# 172 117 88 paper paper
# 173 117 319 paper paper
# 174 117 488 paper paper
# 175 118 226 paper paper
# 176 118 264 paper paper
# 177 119 83 paper paper
# 178 119 111 paper paper
# 179 119 204 paper paper
# 180 119 587 paper paper
# 181 120 90 paper paper
# 182 120 229 paper paper
# 183 121 4 paper paper
# 184 121 25 paper paper
# 185 121 49 paper paper
# 186 121 129 paper paper
# 187 121 130 paper paper
# 188 121 206 paper paper
# 189 121 319 paper paper
# 190 121 360 paper paper
# 191 121 390 paper paper
# 192 122 31 paper paper
# 193 122 345 paper paper
# 194 122 389 paper paper
# 195 123 24 paper paper
# 196 123 132 paper paper
# 197 123 426 paper paper
# 198 123 450 paper paper
# 199 126 41 paper paper
# 200 126 319 paper paper
# 201 127 13 paper paper
# 202 128 240 paper paper
# 203 129 84 paper paper
# 204 129 346 paper paper
# 205 129 376 paper paper
# 206 129 504 paper paper
# 207 130 18 paper paper
# 208 130 49 paper paper
# 209 130 62 paper paper
# 210 131 93 paper paper
# 211 131 288 paper paper
# 212 132 46 paper paper
# 213 133 98 paper paper
# 214 133 111 paper paper
# 215 133 204 paper paper
# 216 134 56 paper paper
# 217 134 167 paper paper
# 218 134 272 paper paper
# 219 134 273 paper paper
# 220 134 495 paper paper
# 221 134 529 paper paper
# 222 134 542 paper paper
# 223 136 207 paper paper
# 224 137 53 paper paper
# 225 137 184 paper paper
# 226 137 253 paper paper
# 227 137 371 paper paper
# 228 138 91 paper paper
# 229 138 204 paper paper
# 230 140 1 paper paper
# 231 140 60 paper paper
# 232 140 319 paper paper
# 233 140 569 paper paper
# 234 141 6 paper paper
# 235 141 7 paper paper
# 236 141 181 paper paper
# 237 141 304 paper paper
# 238 142 69 paper paper
# 239 142 217 paper paper
# 240 144 62 paper paper
# 241 144 154 paper paper
# 242 144 201 paper paper
# 243 144 394 paper paper
# 244 145 0 paper paper
# 245 146 275 paper paper
# 246 148 17 paper paper
# 247 148 298 paper paper
# 248 148 300 paper paper
# 249 148 471 paper paper
# 250 148 532 paper paper
# 251 149 43 paper paper
# 252 153 28 paper paper
# 253 154 201 paper paper
# 254 154 361 paper paper
# 255 154 513 paper paper
# 256 157 62 paper paper
# 257 157 184 paper paper
# 258 157 370 paper paper
# 259 158 69 paper paper
# 260 158 142 paper paper
# 261 159 474 paper paper
# 262 160 73 paper paper
# 263 160 271 paper paper
# 264 161 11 paper paper
# 265 161 178 paper paper
# 266 161 254 paper paper
# 267 162 107 paper paper
# 268 162 354 paper paper
# 269 162 391 paper paper
# 270 162 495 paper paper
# 271 162 503 paper paper
# 272 162 547 paper paper
# 273 163 12 paper paper
# 274 164 36 paper paper
# 275 164 263 paper paper
# 276 165 16 paper paper
# 277 165 200 paper paper
# 278 165 377 paper paper
# 279 166 57 paper paper
# 280 166 483 paper paper
# 281 167 55 paper paper
# 282 167 66 paper paper
# 283 167 398 paper paper
# 284 167 466 paper paper
# 285 168 16 paper paper
# 286 168 184 paper paper
# 287 168 377 paper paper
# 288 171 346 paper paper
# 289 172 63 paper paper
# 290 172 171 paper paper
# 291 172 504 paper paper
# 292 173 40 paper paper
# 293 174 1 paper paper
# 294 174 60 paper paper
# 295 174 68 paper paper
# 296 174 79 paper paper
# 297 174 319 paper paper
# 298 174 569 paper paper
# 299 175 8 paper paper
# 300 175 87 paper paper
# 301 176 99 paper paper
# 302 176 475 paper paper
# 303 177 373 paper paper
# 304 177 403 paper paper
# 305 178 254 paper paper
# 306 178 386 paper paper
# 307 179 38 paper paper
# 308 179 273 paper paper
# 309 179 309 paper paper
# 310 179 348 paper paper
# 311 179 495 paper paper
# 312 179 542 paper paper
# 313 180 35 paper paper
# 314 180 199 paper paper
# 315 180 276 paper paper
# 316 180 475 paper paper
# 317 181 304 paper paper
# 318 182 21 paper paper
# 319 182 506 paper paper
# 320 183 486 paper paper
# 321 184 86 paper paper
# 322 184 311 paper paper
# 323 184 334 paper paper
# 324 184 377 paper paper
# 325 186 1 paper paper
# 326 186 68 paper paper
# 327 186 126 paper paper
# 328 186 174 paper paper
# 329 186 187 paper paper
# 330 186 293 paper paper
# 331 186 363 paper paper
# 332 186 489 paper paper
# 333 186 569 paper paper
# 334 187 68 paper paper
# 335 187 184 paper paper
# 336 187 282 paper paper
# 337 188 534 paper paper
# 338 190 355 paper paper
# 339 191 48 paper paper
# 340 191 81 paper paper
# 341 191 158 paper paper
# 342 192 49 paper paper
# 343 192 98 paper paper
# 344 192 129 paper paper
# 345 192 535 paper paper
# 346 195 267 paper paper
# 347 195 433 paper paper
# 348 196 78 paper paper
# 349 197 4 paper paper
# 350 197 49 paper paper
# 351 197 192 paper paper
# 352 197 370 paper paper
# 353 197 401 paper paper
# 354 197 535 paper paper
# 355 197 587 paper paper
# 356 198 227 paper paper
# 357 200 165 paper paper
# 358 200 377 paper paper
# 359 201 513 paper paper
# 360 203 199 paper paper
# 361 204 146 paper paper
# 362 204 385 paper paper
# 363 205 443 paper paper
# 364 206 25 paper paper
# 365 208 117 paper paper
# 366 208 151 paper paper
# 367 208 459 paper paper
# 368 209 118 paper paper
# 369 209 226 paper paper
# 370 209 264 paper paper
# 371 209 517 paper paper
# 372 209 527 paper paper
# 373 210 17 paper paper
# 374 210 148 paper paper
# 375 210 298 paper paper
# 376 210 300 paper paper
# 377 210 471 paper paper
# 378 210 532 paper paper
# 379 213 301 paper paper
# 380 215 57 paper paper
# 381 216 87 paper paper
# 382 218 183 paper paper
# 383 219 196 paper paper
# 384 220 161 paper paper
# 385 220 254 paper paper
# 386 220 386 paper paper
# 387 223 82 paper paper
# 388 223 141 paper paper
# 389 223 181 paper paper
# 390 223 304 paper paper
# 391 224 586 paper paper
# 392 227 326 paper paper
# 393 228 97 paper paper
# 394 229 8 paper paper
# 395 229 64 paper paper
# 396 231 123 paper paper
# 397 231 450 paper paper
# 398 233 101 paper paper
# 399 234 114 paper paper
# 400 237 413 paper paper
# 401 239 106 paper paper
# 402 241 129 paper paper
# 403 241 130 paper paper
# 404 243 163 paper paper
# 405 244 374 paper paper
# 406 245 8 paper paper
# 407 245 493 paper paper
# 408 246 152 paper paper
# 409 247 31 paper paper
# 410 247 122 paper paper
# 411 247 277 paper paper
# 412 248 225 paper paper
# 413 251 164 paper paper
# 414 254 369 paper paper
# 415 255 150 paper paper
# 416 255 521 paper paper
# 417 257 358 paper paper
# 418 258 180 paper paper
# 419 258 340 paper paper
# 420 259 590 paper paper
# 421 260 129 paper paper
# 422 260 171 paper paper
# 423 260 172 paper paper
# 424 260 241 paper paper
# 425 260 346 paper paper
# 426 260 402 paper paper
# 427 260 419 paper paper
# 428 260 437 paper paper
# 429 260 504 paper paper
# 430 262 425 paper paper
# 431 263 506 paper paper
# 432 263 524 paper paper
# 433 264 226 paper paper
# 434 265 417 paper paper
# 435 267 433 paper paper
# 436 268 353 paper paper
# 437 269 115 paper paper
# 438 269 357 paper paper
# 439 269 376 paper paper
# 440 270 124 paper paper
# 441 271 136 paper paper
# 442 271 207 paper paper
# 443 271 357 paper paper
# 444 272 79 paper paper
# 445 272 348 paper paper
# 446 272 529 paper paper
# 447 273 107 paper paper
# 448 273 354 paper paper
# 449 273 391 paper paper
# 450 273 547 paper paper
# 451 276 0 paper paper
# 452 276 145 paper paper
# 453 277 389 paper paper
# 454 280 415 paper paper
# 455 281 181 paper paper
# 456 283 174 paper paper
# 457 283 175 paper paper
# 458 283 187 paper paper
# 459 283 363 paper paper
# 460 283 475 paper paper
# 461 283 481 paper paper
# 462 283 569 paper paper
# 463 285 268 paper paper
# 464 285 303 paper paper
# 465 287 180 paper paper
# 466 289 321 paper paper
# 467 290 166 paper paper
# 468 290 289 paper paper
# 469 290 321 paper paper
# 470 290 480 paper paper
# 471 290 483 paper paper
# 472 293 352 paper paper
# 473 293 569 paper paper
# 474 294 107 paper paper
# 475 294 305 paper paper
# 476 294 354 paper paper
# 477 294 391 paper paper
# 478 294 465 paper paper
# 479 294 503 paper paper
# 480 294 547 paper paper
# 481 294 550 paper paper
# 482 295 85 paper paper
# 483 297 157 paper paper
# 484 297 399 paper paper
# 485 300 471 paper paper
# 486 301 213 paper paper
# 487 302 380 paper paper
# 488 302 462 paper paper
# 489 303 268 paper paper
# 490 303 567 paper paper
# 491 304 190 paper paper
# 492 304 364 paper paper
# 493 305 107 paper paper
# 494 305 162 paper paper
# 495 305 302 paper paper
# 496 305 465 paper paper
# 497 305 495 paper paper
# 498 305 503 paper paper
# 499 305 547 paper paper
# 500 305 550 paper paper
# 501 307 129 paper paper
# 502 307 187 paper paper
# 503 307 260 paper paper
# 504 307 346 paper paper
# 505 307 362 paper paper
# 506 307 390 paper paper
# 507 307 437 paper paper
# 508 307 582 paper paper
# 509 309 38 paper paper
# 510 309 162 paper paper
# 511 309 294 paper paper
# 512 309 302 paper paper
# 513 309 305 paper paper
# 514 309 465 paper paper
# 515 310 293 paper paper
# 516 310 444 paper paper
# 517 312 245 paper paper
# 518 313 488 paper paper
# 519 316 229 paper paper
# 520 316 283 paper paper
# 521 316 475 paper paper
# 522 316 485 paper paper
# 523 317 233 paper paper
# 524 318 152 paper paper
# 525 318 541 paper paper
# 526 322 116 paper paper
# 527 325 247 paper paper
# 528 325 456 paper paper
# 529 327 258 paper paper
# 530 327 505 paper paper
# 531 329 54 paper paper
# 532 329 103 paper paper
# 533 329 344 paper paper
# 534 329 398 paper paper
# 535 329 424 paper paper
# 536 329 457 paper paper
# 537 329 466 paper paper
# 538 329 595 paper paper
# 539 330 242 paper paper
# 540 333 156 paper paper
# 541 334 68 paper paper
# 542 334 118 paper paper
# 543 334 209 paper paper
# 544 334 226 paper paper
# 545 334 517 paper paper
# 546 334 527 paper paper
# 547 335 105 paper paper
# 548 335 247 paper paper
# 549 335 325 paper paper
# 550 335 456 paper paper
# 551 335 485 paper paper
# 552 339 49 paper paper
# 553 339 296 paper paper
# 554 339 370 paper paper
# 555 343 246 paper paper
# 556 344 42 paper paper
# 557 344 66 paper paper
# 558 344 79 paper paper
# 559 344 147 paper paper
# 560 344 194 paper paper
# 561 344 424 paper paper
# 562 344 595 paper paper
# 563 345 410 paper paper
# 564 345 539 paper paper
# 565 346 143 paper paper
# 566 348 162 paper paper
# 567 348 294 paper paper
# 568 348 305 paper paper
# 569 348 542 paper paper
# 570 348 547 paper paper
# 571 351 431 paper paper
# 572 354 107 paper paper
# 573 354 302 paper paper
# 574 354 391 paper paper
# 575 354 429 paper paper
# 576 354 495 paper paper
# 577 354 542 paper paper
# 578 360 206 paper paper
# 579 361 513 paper paper
# 580 362 126 paper paper
# 581 362 129 paper paper
# 582 364 190 paper paper
# 583 364 355 paper paper
# 584 366 130 paper paper
# 585 366 192 paper paper
# 586 366 479 paper paper
# 587 369 386 paper paper
# 588 370 8 paper paper
# 589 370 296 paper paper
# 590 373 430 paper paper
# 591 375 239 paper paper
# 592 377 200 paper paper
# 593 377 209 paper paper
# 594 377 517 paper paper
# 595 377 527 paper paper
# 596 380 211 paper paper
# 597 381 199 paper paper
# 598 383 85 paper paper
# 599 383 561 paper paper
# 600 385 491 paper paper
# 601 385 572 paper paper
# 602 386 152 paper paper
# 603 386 246 paper paper
# 604 386 318 paper paper
# 605 386 541 paper paper
# 606 387 349 paper paper
# 607 388 454 paper paper
# 608 390 129 paper paper
# 609 390 241 paper paper
# 610 390 419 paper paper
# 611 393 216 paper paper
# 612 393 475 paper paper
# 613 394 154 paper paper
# 614 394 201 paper paper
# 615 394 361 paper paper
# 616 395 269 paper paper
# 617 396 107 paper paper
# 618 396 162 paper paper
# 619 396 273 paper paper
# 620 396 294 paper paper
# 621 396 429 paper paper
# 622 396 529 paper paper
# 623 396 542 paper paper
# 624 398 33 paper paper
# 625 398 42 paper paper
# 626 398 66 paper paper
# 627 398 79 paper paper
# 628 398 103 paper paper
# 629 398 147 paper paper
# 630 398 315 paper paper
# 631 398 329 paper paper
# 632 398 344 paper paper
# 633 398 424 paper paper
# 634 398 438 paper paper
# 635 398 466 paper paper
# 636 398 511 paper paper
# 637 398 595 paper paper
# 638 399 119 paper paper
# 639 399 370 paper paper
# 640 401 365 paper paper
# 641 402 154 paper paper
# 642 402 201 paper paper
# 643 402 361 paper paper
# 644 402 394 paper paper
# 645 404 28 paper paper
# 646 405 422 paper paper
# 647 405 477 paper paper
# 648 406 314 paper paper
# 649 406 330 paper paper
# 650 407 203 paper paper
# 651 408 214 paper paper
# 652 412 217 paper paper
# 653 414 246 paper paper
# 654 420 121 paper paper
# 655 420 129 paper paper
# 656 420 206 paper paper
# 657 420 241 paper paper
# 658 420 390 paper paper
# 659 420 406 paper paper
# 660 420 419 paper paper
# 661 420 582 paper paper
# 662 421 228 paper paper
# 663 423 328 paper paper
# 664 424 42 paper paper
# 665 424 79 paper paper
# 666 426 24 paper paper
# 667 426 374 paper paper
# 668 426 450 paper paper
# 669 426 469 paper paper
# 670 426 590 paper paper
# 671 427 247 paper paper
# 672 428 594 paper paper
# 673 429 501 paper paper
# 674 430 597 paper paper
# 675 432 279 paper paper
# 676 432 552 paper paper
# 677 434 395 paper paper
# 678 434 456 paper paper
# 679 434 562 paper paper
# 680 434 582 paper paper
# 681 435 137 paper paper
# 682 435 371 paper paper
# 683 435 436 paper paper
# 684 436 213 paper paper
# 685 437 346 paper paper
# 686 438 55 paper paper
# 687 439 256 paper paper
# 688 439 331 paper paper
# 689 445 103 paper paper
# 690 445 167 paper paper
# 691 445 398 paper paper
# 692 445 457 paper paper
# 693 445 511 paper paper
# 694 446 87 paper paper
# 695 446 175 paper paper
# 696 446 363 paper paper
# 697 446 475 paper paper
# 698 446 481 paper paper
# 699 446 589 paper paper
# 700 448 341 paper paper
# 701 449 231 paper paper
# 702 450 244 paper paper
# 703 450 349 paper paper
# 704 450 469 paper paper
# 705 450 500 paper paper
# 706 450 525 paper paper
# 707 451 214 paper paper
# 708 456 395 paper paper
# 709 456 582 paper paper
# 710 456 584 paper paper
# 711 457 33 paper paper
# 712 458 136 paper paper
# 713 458 358 paper paper
# 714 461 226 paper paper
# 715 461 264 paper paper
# 716 462 536 paper paper
# 717 463 563 paper paper
# 718 465 302 paper paper
# 719 465 391 paper paper
# 720 466 33 paper paper
# 721 466 66 paper paper
# 722 466 103 paper paper
# 723 466 292 paper paper
# 724 466 344 paper paper
# 725 466 424 paper paper
# 726 466 457 paper paper
# 727 466 595 paper paper
# 728 467 276 paper paper
# 729 468 5 paper paper
# 730 469 590 paper paper
# 731 470 80 paper paper
# 732 470 310 paper paper
# 733 470 539 paper paper
# 734 470 569 paper paper
# 735 472 338 paper paper
# 736 475 8 paper paper
# 737 475 87 paper paper
# 738 475 229 paper paper
# 739 475 271 paper paper
# 740 481 8 paper paper
# 741 481 87 paper paper
# 742 481 175 paper paper
# 743 481 216 paper paper
# 744 482 554 paper paper
# 745 488 578 paper paper
# 746 489 68 paper paper
# 747 489 118 paper paper
# 748 489 226 paper paper
# 749 489 264 paper paper
# 750 489 334 paper paper
# 751 489 514 paper paper
# 752 489 527 paper paper
# 753 489 569 paper paper
# 754 490 359 paper paper
# 755 491 488 paper paper
# 756 492 184 paper paper
# 757 492 377 paper paper
# 758 494 121 paper paper
# 759 494 241 paper paper
# 760 494 390 paper paper
# 761 494 419 paper paper
# 762 494 420 paper paper
# 763 494 504 paper paper
# 764 494 582 paper paper
# 765 495 391 paper paper
# 766 497 131 paper paper
# 767 500 244 paper paper
# 768 500 374 paper paper
# 769 500 387 paper paper
# 770 500 469 paper paper
# 771 500 590 paper paper
# 772 503 302 paper paper
# 773 503 391 paper paper
# 774 504 346 paper paper
# 775 509 397 paper paper
# 776 510 451 paper paper
# 777 511 147 paper paper
# 778 511 438 paper paper
# 779 511 498 paper paper
# 275 132 58 paper field
# 276 132 84 paper field
# 277 133 7 paper field
# 278 134 1 paper field
# 279 134 138 paper field
# 280 134 143 paper field
# 281 135 7 paper field
# 282 136 3 paper field
# 283 136 18 paper field
# 284 136 40 paper field
# 285 136 152 paper field
# 286 137 1 paper field
# 287 137 7 paper field
# 288 138 1 paper field
# 289 138 38 paper field
# 290 139 9 paper field
# 291 139 42 paper field
# 292 140 14 paper field
# 293 140 235 paper field
# 294 141 2 paper field
# 295 142 1 paper field
# 296 143 6 paper field
# 297 143 87 paper field
# 298 144 6 paper field
# 299 145 3 paper field
# 300 146 1 paper field
# 301 146 7 paper field
# 302 146 9 paper field
# 303 147 22 paper field
# 304 147 34 paper field
# 305 148 1 paper field
# 306 148 14 paper field
# 307 149 2 paper field
# 308 149 6 paper field
# 309 150 6 paper field
# 310 150 9 paper field
# 311 150 34 paper field
# 312 151 38 paper field
# 313 151 45 paper field
# 314 152 2 paper field
# 315 153 1 paper field
# 316 153 7 paper field
# 317 154 1 paper field
# 318 154 6 paper field
# 319 154 14 paper field
# 320 155 1 paper field
# 321 155 7 paper field
# 322 155 9 paper field
# 323 156 1 paper field
# 324 156 3 paper field
# 325 156 4 paper field
# 326 157 1 paper field
# 327 157 7 paper field
# 328 157 87 paper field
# 329 158 1 paper field
# 330 158 2 paper field
# 331 158 9 paper field
# 332 159 7 paper field
# 333 159 14 paper field
# 334 159 235 paper field
# 335 160 3 paper field
# 336 160 40 paper field
# 337 160 152 paper field
# 338 161 2 paper field
# 339 161 5 paper field
# 340 162 2 paper field
# 341 162 6 paper field
# 342 163 58 paper field
# 343 163 84 paper field
# 344 164 2 paper field
# 345 164 200 paper field
# 346 165 58 paper field
# 347 165 87 paper field
# 348 166 2 paper field
# 349 166 5 paper field
# 350 166 146 paper field
# 351 167 22 paper field
# 352 167 34 paper field
# 353 168 1 paper field
# 354 169 3 paper field
# 355 169 4 paper field
# 356 170 6 paper field
# 357 170 271 paper field
# 358 171 6 paper field
# 359 171 14 paper field
# 360 172 6 paper field
# 361 173 1 paper field
# 362 174 14 paper field
# 363 175 3 paper field
# 364 175 18 paper field
# 365 176 3 paper field
# 366 176 40 paper field
# 367 177 3 paper field
# 368 177 4 paper field
# 369 178 2 paper field
# 370 178 5 paper field
# 371 179 2 paper field
# 372 179 200 paper field
# 373 180 3 paper field
# 374 180 10 paper field
# 375 181 2 paper field
# 376 181 125 paper field
# 377 182 3 paper field
# 378 182 40 paper field
# 379 182 146 paper field
# 380 183 9 paper field
# 381 184 1 paper field
# 382 184 7 paper field
# 383 185 1 paper field
# 384 185 2 paper field
# 385 185 98 paper field
# 386 186 14 paper field
# 387 186 34 paper field
# 388 187 1 paper field
# 389 187 2 paper field
# 390 188 6 paper field
# 391 189 3 paper field
# 392 189 4 paper field
# 393 189 40 paper field
# 394 190 2 paper field
# 395 191 1 paper field
# 396 191 7 paper field
# 397 192 1 paper field
# 398 192 7 paper field
# 399 193 3 paper field
# 400 193 40 paper field
# 401 193 42 paper field
# 402 193 152 paper field
# 403 194 22 paper field
# 404 194 167 paper field
# 405 194 196 paper field
# 406 194 288 paper field
# 407 195 196 paper field
# 408 196 2 paper field
# 409 197 1 paper field
# 410 197 7 paper field
# 411 198 2 paper field
# 412 198 22 paper field
# 413 199 7 paper field
# 414 200 1 paper field
# 415 200 87 paper field
# 416 201 14 paper field
# 417 202 34 paper field
# 418 203 243 paper field
# 419 204 1 paper field
# 420 204 58 paper field
# 421 206 6 paper field
# 422 206 34 paper field
# 423 207 3 paper field
# 424 207 18 paper field
# 425 207 143 paper field
# 426 208 2 paper field
# 427 208 38 paper field
# 428 208 107 paper field
# 429 209 6 paper field
# 430 209 14 paper field
# 431 210 6 paper field
# 432 210 9 paper field
# 433 211 6 paper field
# 434 211 34 paper field
# 435 212 6 paper field
# 436 212 34 paper field
# 437 213 138 paper field
# 438 213 146 paper field
# 439 214 271 paper field
# 440 215 2 paper field
# 441 215 5 paper field
# 442 216 9 paper field
# 443 217 2 paper field
# 444 217 3 paper field
# 445 217 4 paper field
# 446 217 9 paper field
# 447 218 1 paper field
# 448 218 9 paper field
# 449 218 38 paper field
# 450 218 45 paper field
# 451 219 2 paper field
# 452 220 2 paper field
# 453 221 6 paper field
# 454 222 1 paper field
# 455 222 6 paper field
# 456 222 34 paper field
# 457 223 2 paper field
# 458 224 22 paper field
# 459 225 6 paper field
# 460 225 34 paper field
# 461 225 87 paper field
# 462 226 58 paper field
# 463 226 87 paper field
# 464 227 22 paper field
# 465 228 1 paper field
# 466 228 98 paper field
# 467 229 3 paper field
# 468 229 18 paper field
# 469 229 40 paper field
# 470 230 6 paper field
# 471 230 22 paper field
# 472 231 58 paper field
# 473 231 84 paper field
# 474 232 3 paper field
# 475 232 4 paper field
# 476 232 40 paper field
# 477 233 1 paper field
# 478 233 2 paper field
# 816 414 5 paper field
# 817 414 6 paper field
# 818 414 125 paper field
# 819 415 2 paper field
# 820 415 34 paper field
# 821 415 125 paper field
# 822 416 3 paper field
# 823 416 4 paper field
# 824 416 5 paper field
# 825 416 200 paper field
# 826 417 58 paper field
# 827 418 3 paper field
# 828 418 4 paper field
# 829 418 9 paper field
# 830 419 6 paper field
# 831 419 34 paper field
# 832 420 281 paper field
# 833 421 98 paper field
# 834 422 196 paper field
# 835 423 7 paper field
# 836 423 14 paper field
# 837 423 235 paper field
# 838 424 6 paper field
# 839 424 34 paper field
# 840 425 235 paper field
# 841 426 58 paper field
# 842 426 84 paper field
# 843 427 1 paper field
# 844 427 9 paper field
# 845 428 6 paper field
# 846 428 14 paper field
# 847 429 6 paper field
# 848 429 34 paper field
# 849 430 34 paper field
# 850 431 3 paper field
# 851 431 10 paper field
# 852 431 84 paper field
# 853 432 3 paper field
# 854 432 4 paper field
# 855 433 3 paper field
# 856 433 40 paper field
# 857 433 152 paper field
# 858 434 6 paper field
# 859 434 34 paper field
# 860 435 138 paper field
# 861 436 146 paper field
# 862 437 1 paper field
# 863 437 6 paper field
# 864 438 6 paper field
# 865 438 22 paper field
# 866 439 3 paper field
# 867 439 18 paper field
# 868 440 1 paper field
# 869 440 7 paper field
# 870 440 9 paper field
# 871 441 2 paper field
# 872 441 6 paper field
# 873 441 200 paper field
# 874 442 58 paper field
# 875 442 138 paper field
# 876 443 7 paper field
# 877 444 1 paper field
# 878 444 14 paper field
# 879 444 34 paper field
# 880 445 143 paper field
# 881 445 243 paper field
# 882 446 2 paper field
# 883 446 281 paper field
# 884 447 2 paper field
# 885 447 3 paper field
# 886 447 18 paper field
# 887 447 125 paper field
# 888 448 3 paper field
# 889 448 18 paper field
# 890 449 151 paper field
# 891 450 58 paper field
# 892 450 84 paper field
# 893 451 3 paper field
# 894 451 4 paper field
# 895 451 34 paper field
# 896 452 6 paper field
# 897 452 14 paper field
# 898 452 235 paper field
# 899 453 42 paper field
# 900 454 2 paper field
# 901 455 2 paper field
# 902 455 318 paper field
# 903 456 6 paper field
# 904 456 138 paper field
# 905 457 1 paper field
# 906 457 22 paper field
# 907 457 34 paper field
# 908 458 9 paper field
# 909 459 1 paper field
# 910 459 38 paper field
# 911 460 58 paper field
# 912 460 84 paper field
# 913 461 1 paper field
# 914 461 7 paper field
# 915 461 87 paper field
# 916 462 2 paper field
# 917 462 235 paper field
# 918 463 2 paper field
# 919 464 58 paper field
# 920 464 87 paper field
# 921 465 2 paper field
# 922 465 6 paper field
# 923 466 1 paper field
# 924 466 22 paper field
# 925 466 34 paper field
# 926 467 9 paper field
# 927 467 38 paper field
# 928 468 2 paper field
# 929 468 200 paper field
# 930 469 58 paper field
# 931 469 84 paper field
# 932 470 14 paper field
# 933 471 6 paper field
# 934 471 235 paper field
# 935 471 281 paper field
# 936 472 3 paper field
# 937 472 10 paper field
# 938 473 1 paper field
# 939 474 6 paper field
# 940 474 14 paper field
# 941 474 34 paper field
# 942 475 3 paper field
# 943 475 18 paper field
# 944 476 3 paper field
# 945 476 6 paper field
# 946 476 18 paper field
# 947 476 138 paper field
# 948 477 34 paper field
# 949 478 6 paper field
# 950 478 87 paper field
# 951 479 7 paper field
# 952 480 2 paper field
# 953 481 14 paper field
# 954 481 38 paper field
# 955 482 42 paper field
# 956 483 2 paper field
# 957 484 2 paper field
# 958 486 1 paper field
# 959 486 14 paper field
# 960 487 87 paper field
# 961 488 1 paper field
# 962 488 235 paper field
# 963 489 1 paper field
# 964 489 6 paper field
# 965 489 138 paper field
# 966 490 6 paper field
# 967 490 34 paper field
# 968 491 1 paper field
# 969 491 7 paper field
# 970 492 1 paper field
# 971 492 7 paper field
# 972 492 58 paper field
# 973 493 3 paper field
# 974 493 18 paper field
# 975 493 40 paper field
# 976 494 6 paper field
# 977 495 2 paper field
# 978 495 6 paper field
# 979 496 1 paper field
# 980 496 7 paper field
# 981 498 6 paper field
# 982 498 9 paper field
# 983 498 14 paper field
# 984 498 34 paper field
# 985 499 3 paper field
# 986 499 7 paper field
# 987 499 10 paper field
# 988 500 58 paper field
# 989 500 84 paper field
# 990 501 1 paper field
# 991 501 6 paper field
# 992 501 34 paper field
# 993 502 3 paper field
# 994 502 10 paper field
# 995 502 40 paper field
# 996 502 152 paper field
# 997 503 2 paper field
# 998 503 143 paper field
# 999 504 7 paper field
# 1000 505 3 paper field
# 1001 505 18 paper field
# 1002 505 40 paper field
# 1003 506 1 paper field
# 1004 506 5 paper field
# 1005 506 38 paper field
# 1006 507 34 paper field
# 1007 508 1 paper field
# 1008 509 2 paper field
# 1009 510 3 paper field
# 1010 511 22 paper field
# 1011 511 34 paper field
# 1012 512 1 paper field
# 1013 513 6 paper field
# 1014 513 14 paper field
# 1015 514 1 paper field
# 1016 514 84 paper field
# 1017 515 1 paper field
# 1018 515 3 paper field
# 1019 515 18 paper field
# 1020 516 2 paper field
# 1021 516 5 paper field
# 1022 516 6 paper field
# 1023 517 1 paper field
# 1024 518 235 paper field
# 1025 519 2 paper field
# 1026 519 5 paper field
# 1027 520 1 paper field
# 1028 520 271 paper field
# 1029 521 6 paper field
# 1030 521 34 paper field
# 1031 522 58 paper field
# 1032 522 87 paper field
# 1033 523 3 paper field
# 1034 523 38 paper field
# 1035 524 2 paper field
# 1036 524 5 paper field
# 1037 525 3 paper field
# 1038 525 40 paper field
# 1039 525 58 paper field
# 1040 526 1 paper field
# 1041 526 7 paper field
# 1042 527 1 paper field
# 1043 527 6 paper field
# 1044 528 2 paper field
# 1045 528 6 paper field
# 1046 529 6 paper field
# 1047 529 235 paper field
# 1048 530 6 paper field
# 1049 531 1 paper field
# 1050 531 7 paper field
# 1051 531 58 paper field
# 1052 531 87 paper field
# 1053 532 1 paper field
# 1054 532 2 paper field
# 1055 532 38 paper field
# 1056 533 3 paper field
# 1057 533 4 paper field
# 1058 534 6 paper field
# 1059 534 58 paper field
# 1060 535 6 paper field
# 1061 535 7 paper field
# 1062 535 34 paper field
# 1063 536 2 paper field
# 1064 536 6 paper field
# 1065 537 6 paper field
# 1066 537 22 paper field
# 1067 537 34 paper field
# 1068 538 3 paper field
# 1069 538 18 paper field
# 1070 538 152 paper field
# 1071 539 14 paper field
# 1072 540 7 paper field
# 1073 540 87 paper field
# 1074 541 125 paper field
# 1075 542 2 paper field
# 1076 542 6 paper field
# 1077 543 58 paper field
# 1078 543 87 paper field
# 1079 544 1 paper field
# 1080 544 7 paper field
# 1081 544 14 paper field
# 1082 545 2 paper field
# 1083 546 3 paper field
# 1084 546 18 paper field
# 1085 547 2 paper field
# 1086 548 2 paper field
# 1087 548 200 paper field
# 1088 549 1 paper field
# 1089 549 38 paper field
# 1090 549 45 paper field
# 1091 550 6 paper field
# 1092 550 200 paper field
# 1093 551 1 paper field
# 1094 551 14 paper field
# 1095 552 1 paper field
# 1096 552 3 paper field
# 1097 552 4 paper field
# 1098 553 6 paper field
# 1099 553 14 paper field
# 1100 554 2 paper field
# 1101 555 58 paper field
# 1102 555 87 paper field
# 1103 556 3 paper field
# 1104 556 7 paper field
# 1105 557 2 paper field
# 1106 557 200 paper field
# 1107 558 6 paper field
# 1108 558 42 paper field
# 1109 559 58 paper field
# 1110 559 84 paper field
# 1111 560 3 paper field
# 1112 560 18 paper field
# 1113 561 152 paper field
# 1114 562 288 paper field
# 1115 563 22 paper field
# 1116 564 1 paper field
# 1117 564 7 paper field
# 1118 565 1 paper field
# 1119 565 281 paper field
# 1120 566 6 paper field
# 1121 566 14 paper field
# 1122 566 167 paper field
# 1123 567 1 paper field
# 1124 567 34 paper field
# 1125 568 2 paper field
# 1126 569 14 paper field
# 1127 570 58 paper field
# 1128 570 87 paper field
# 1129 571 1 paper field
# 1130 572 1 paper field
# 1131 572 7 paper field
# 1132 573 3 paper field
# 1133 574 1 paper field
# 1134 574 3 paper field
# 1135 574 4 paper field
# 1136 574 58 paper field
# 1137 575 6 paper field
# 1138 575 87 paper field
# 1139 576 1 paper field
# 1140 576 9 paper field
# 1141 577 1 paper field
# 1142 577 34 paper field
# 1143 578 6 paper field
# 1144 578 14 paper field
# 1145 578 34 paper field
# 1146 579 5 paper field
# 1147 579 200 paper field
# 1148 580 58 paper field
# 1149 581 7 paper field
# 1150 582 167 paper field
# 1151 583 1 paper field
# 1152 583 2 paper field
# 1153 584 243 paper field
# 1154 585 138 paper field
# 1155 585 143 paper field
# 1156 586 2 paper field
# 1157 586 125 paper field
# 1158 587 1 paper field
# 1159 587 7 paper field
# 1160 588 1 paper field
# 1161 588 9 paper field
# 1162 588 38 paper field
# 1163 589 3 paper field
# 1164 589 18 paper field
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 415 296 284 paper field
# 416 296 351 paper field
# 417 297 23 paper field
# 418 298 228 paper field
# 419 302 132 paper field
# 420 303 64 paper field
# 421 303 315 paper field
# 422 305 13 paper field
# 423 305 103 paper field
# 424 305 132 paper field
# 425 305 363 paper field
# 426 305 433 paper field
# 427 306 64 paper field
# 428 306 232 paper field
# 429 307 389 paper field
# 430 308 407 paper field
# 431 309 13 paper field
# 432 309 223 paper field
# 433 309 275 paper field
# 434 309 376 paper field
# 435 310 115 paper field
# 436 310 434 paper field
# 437 311 351 paper field
# 438 313 228 paper field
# 439 314 57 paper field
# 440 314 233 paper field
# 441 314 314 paper field
# 442 315 324 paper field
# 443 315 386 paper field
# 444 317 96 paper field
# 445 318 203 paper field
# 446 318 228 paper field
# 447 319 12 paper field
# 448 319 115 paper field
# 449 319 248 paper field
# 450 320 150 paper field
# 451 321 282 paper field
# 452 323 322 paper field
# 453 324 175 paper field
# 454 325 23 paper field
# 455 325 332 paper field
# 456 325 455 paper field
# 457 326 64 paper field
# 458 326 232 paper field
# 459 327 33 paper field
# 460 328 175 paper field
# 461 328 284 paper field
# 462 329 124 paper field
# 463 330 392 paper field
# 464 331 280 paper field
# 465 331 315 paper field
# 466 331 319 paper field
# 467 333 248 paper field
# 468 333 321 paper field
# 469 333 391 paper field
# 470 334 356 paper field
# 471 334 363 paper field
# 472 335 477 paper field
# 473 336 33 paper field
# 474 336 413 paper field
# 475 339 215 paper field
# 476 340 232 paper field
# 477 341 131 paper field
# 478 343 226 paper field
# 479 343 232 paper field
# 480 346 83 paper field
# 481 346 388 paper field
# 482 347 370 paper field
# 483 348 13 paper field
# 484 348 223 paper field
# 485 348 443 paper field
# 486 349 57 paper field
# 487 349 297 paper field
# 488 350 315 paper field
# 489 351 173 paper field
# 490 351 199 paper field
# 491 351 284 paper field
# 492 351 335 paper field
# 493 351 396 paper field
# 494 352 228 paper field
# 495 352 275 paper field
# 496 352 362 paper field
# 497 354 13 paper field
# 498 354 307 paper field
# 499 354 386 paper field
# 500 355 64 paper field
# 501 355 140 paper field
# 502 355 203 paper field
# 503 356 199 paper field
# 504 357 321 paper field
# 505 358 306 paper field
# 506 358 326 paper field
# 507 359 228 paper field
# 508 359 314 paper field
# 509 360 324 paper field
# 510 360 331 paper field
# 511 361 153 paper field
# 512 361 331 paper field
# 513 361 447 paper field
# 514 362 220 paper field
# 515 362 275 paper field
# 516 362 331 paper field
# 517 364 64 paper field
# 518 364 296 paper field
# 519 365 85 paper field
# 520 365 284 paper field
# 521 365 351 paper field
# 522 365 482 paper field
# 523 366 124 paper field
# 524 366 324 paper field
# 525 366 381 paper field
# 526 366 388 paper field
# 527 366 392 paper field
# 528 366 405 paper field
# 529 367 324 paper field
# 530 368 350 paper field
# 531 370 199 paper field
# 532 370 284 paper field
# 533 372 424 paper field
# 534 373 74 paper field
# 535 374 57 paper field
# 536 375 297 paper field
# 537 375 310 paper field
# 538 376 124 paper field
# 539 376 363 paper field
# 540 380 13 paper field
# 541 380 228 paper field
# 542 380 390 paper field
# 543 381 12 paper field
# 544 385 44 paper field
# 545 385 231 paper field
# 546 387 370 paper field
# 547 388 12 paper field
# 548 388 223 paper field
# 549 389 103 paper field
# 550 390 123 paper field
# 551 390 324 paper field
# 552 390 388 paper field
# 553 391 13 paper field
# 554 391 141 paper field
# 555 391 223 paper field
# 556 393 166 paper field
# 557 393 394 paper field
# 558 393 459 paper field
# 559 394 83 paper field
# 560 395 12 paper field
# 561 395 124 paper field
# 562 395 169 paper field
# 563 395 392 paper field
# 564 395 405 paper field
# 565 396 12 paper field
# 566 396 169 paper field
# 567 396 223 paper field
# 568 396 332 paper field
# 569 396 396 paper field
# 570 399 148 paper field
# 571 399 169 paper field
# 572 401 12 paper field
# 573 401 13 paper field
# 574 401 44 paper field
# 575 402 123 paper field
# 576 402 389 paper field
# 577 404 169 paper field
# 578 404 381 paper field
# 579 406 52 paper field
# 580 406 233 paper field
# 581 407 175 paper field
# 582 408 23 paper field
# 583 409 439 paper field
# 584 410 184 paper field
# 585 411 370 paper field
# 586 412 275 paper field
# 587 413 124 paper field
# 588 414 64 paper field
# 589 414 355 paper field
# 590 415 439 paper field
# 591 416 237 paper field
# 592 419 83 paper field
# 593 419 170 paper field
# 594 420 70 paper field
# 595 420 388 paper field
# 596 423 169 paper field
# 597 423 228 paper field
# 598 423 396 paper field
# 599 423 405 paper field
# 600 424 338 paper field
# 601 425 208 paper field
# 602 427 103 paper field
# 603 427 455 paper field
# 604 428 83 paper field
# 605 428 170 paper field
# 606 429 64 paper field
# 607 429 122 paper field
# 608 429 376 paper field
# 609 431 23 paper field
# 610 431 74 paper field
# 611 431 83 paper field
# 612 431 284 paper field
# 613 432 455 paper field
# 614 433 280 paper field
# 615 434 331 paper field
# 616 434 392 paper field
# 617 435 496 paper field
# 618 436 292 paper field
# 619 437 123 paper field
# 620 437 175 paper field
# 621 437 447 paper field
# 622 438 64 paper field
# 623 438 315 paper field
# 624 439 319 paper field
# 625 441 228 paper field
# 626 443 128 paper field
# 627 444 356 paper field
# 628 445 392 paper field
# 629 446 55 paper field
# 630 446 115 paper field
# 631 446 350 paper field
# 632 446 375 paper field
# 633 450 57 paper field
# 634 450 407 paper field
# 635 450 455 paper field
# 636 451 12 paper field
# 637 451 44 paper field
# 638 452 13 paper field
# 639 454 297 paper field
# 640 454 390 paper field
# 641 454 429 paper field
# 642 455 390 paper field
# 643 455 439 paper field
# 644 456 23 paper field
# 645 456 169 paper field
# 646 456 392 paper field
# 647 456 434 paper field
# 648 457 406 paper field
# 649 458 12 paper field
# 650 458 275 paper field
# 651 458 306 paper field
# 652 458 326 paper field
# 653 458 363 paper field
# 654 461 370 paper field
# 655 461 399 paper field
# 656 462 13 paper field
# 657 462 228 paper field
# 658 464 370 paper field
# 659 465 13 paper field
# 660 465 132 paper field
# 661 465 363 paper field
# 662 466 392 paper field
# 663 467 482 paper field
# 664 467 496 paper field
# 665 468 496 paper field
# 666 469 407 paper field
# 667 470 392 paper field
# 668 472 148 paper field
# 669 472 228 paper field
# 670 472 424 paper field
# 671 473 124 paper field
# 672 473 332 paper field
# 673 475 131 paper field
# 674 475 275 paper field
# 675 475 326 paper field
# 676 476 490 paper field
# 677 477 483 paper field
# 678 478 331 paper field
# 679 479 13 paper field
# 680 479 175 paper field
# 681 482 64 paper field
# 682 483 64 paper field
# 683 484 390 paper field
# 684 485 103 paper field
# 685 486 472 paper field
# 686 487 44 paper field
# 687 487 370 paper field
# 688 488 12 paper field
# 689 488 228 paper field
# 690 489 389 paper field
# 691 490 248 paper field
# 692 491 228 paper field
# 693 492 173 paper field
# 694 492 332 paper field
# 695 492 399 paper field
# 696 494 324 paper field
# 697 494 350 paper field
# 698 494 392 paper field
# 699 495 13 paper field
# 700 496 43 paper field
# 701 496 144 paper field
# 702 496 169 paper field
# 703 497 332 paper field
# 704 499 322 paper field
# 705 500 57 paper field
# 706 500 407 paper field
# 707 501 284 paper field
# 708 502 326 paper field
# 709 502 447 paper field
# 710 503 13 paper field
# 711 504 83 paper field
# 712 504 170 paper field
# 713 505 166 paper field
# 714 505 360 paper field
# 715 505 386 paper field
# 716 506 64 paper field
# 717 506 355 paper field
# 718 507 228 paper field
# 719 507 233 paper field
# 720 510 43 paper field
# 721 510 424 paper field
# 722 511 12 paper field
# 723 511 164 paper field
# 724 511 392 paper field
# 725 511 412 paper field
# 726 513 284 paper field
# 727 514 228 paper field
# 728 516 296 paper field
# 729 516 376 paper field
# 730 517 363 paper field
# 731 518 23 paper field
# 732 518 324 paper field
# 733 518 388 paper field
# 734 519 223 paper field
# 735 519 390 paper field
# 736 520 153 paper field
# 737 520 332 paper field
# 738 521 205 paper field
# 739 525 199 paper field
# 740 525 297 paper field
# 741 526 284 paper field
# 742 527 124 paper field
# 743 528 64 paper field
# 744 528 386 paper field
# 745 529 13 paper field
# 746 529 169 paper field
# 747 529 223 paper field
# 748 529 434 paper field
# 749 530 64 paper field
# 750 530 166 paper field
# 751 530 360 paper field
# 752 531 284 paper field
# 753 531 399 paper field
# 754 531 404 paper field
# 755 532 203 paper field
# 756 532 223 paper field
# 757 532 413 paper field
# 758 534 315 paper field
# 759 535 324 paper field
# 760 536 13 paper field
# 761 536 141 paper field
# 762 536 223 paper field
# 763 537 292 paper field
# 764 537 391 paper field
# 765 539 275 paper field
# 766 540 144 paper field
# 767 540 284 paper field
# 768 540 351 paper field
# 769 540 405 paper field
# 770 541 376 paper field
# 771 542 13 paper field
# 772 542 376 paper field
# 773 544 37 paper field
# 774 545 228 paper field
# 775 547 12 paper field
# 776 547 13 paper field
# 777 547 141 paper field
# 778 547 223 paper field
# 779 549 166 paper field
# 780 550 13 paper field
# 781 550 132 paper field
# 782 550 433 paper field
# 783 550 443 paper field
# 784 551 85 paper field
# 785 551 405 paper field
# 786 552 237 paper field
# 787 552 297 paper field
# 788 553 83 paper field
# 789 554 64 paper field
# 790 554 355 paper field
# 791 555 399 paper field
# 792 555 404 paper field
# 793 556 284 paper field
# 794 558 103 paper field
# 795 558 331 paper field
# 796 559 407 paper field
# 797 560 319 paper field
# 798 562 392 paper field
# 799 563 64 paper field
# 800 563 315 paper field
# 801 563 360 paper field
# 802 564 284 paper field
# 803 564 351 paper field
# 804 566 170 paper field
# 805 567 315 paper field
# 806 568 355 paper field
# 807 570 396 paper field
# 808 570 399 paper field
# 809 571 85 paper field
# 810 572 12 paper field
# 811 572 169 paper field
# 812 573 496 paper field
# 813 574 228 paper field
# 814 575 284 paper field
# 815 578 169 paper field
# 816 578 331 paper field
# 817 579 23 paper field
# 818 580 350 paper field
# 819 580 496 paper field
# 820 581 148 paper field
# 821 581 405 paper field
# 822 582 455 paper field
# 823 584 124 paper field
# 824 585 375 paper field
# 825 586 376 paper field
# 826 587 44 paper field
# 827 587 434 paper field
# 828 588 24 paper field
# 829 588 223 paper field
# 830 589 326 paper field
# 831 590 364 paper field
# 832 590 407 paper field
# 833 591 44 paper field
# 834 591 148 paper field
# 835 592 74 paper field
# 836 592 131 paper field
# 837 593 153 paper field
# 838 594 315 paper field
# 839 594 324 paper field
# 840 596 57 paper field
# 841 596 64 paper field
# 842 597 153 paper field
# 843 599 85 paper field
# 844 599 144 paper field
# 845 599 169 paper field
# 846 599 496 paper field
# 0 1 15 paper field
# 1 3 172 paper field
# 2 6 68 paper field
# 3 7 68 paper field
# 4 11 66 paper field
# 5 16 51 paper field
# 6 18 239 paper field
# 7 28 234 paper field
# 8 29 187 paper field
# 9 33 80 paper field
# 10 35 127 paper field
# 11 50 165 paper field
# 12 57 66 paper field
# 13 59 179 paper field
# 14 62 207 paper field
# 15 64 201 paper field
# 16 65 91 paper field
# 17 65 211 paper field
# 18 67 86 paper field
# 19 67 189 paper field
# 20 72 402 paper field
# 21 83 86 paper field
# 22 83 329 paper field
# 23 90 201 paper field
# 24 93 374 paper field
# 25 98 264 paper field
# 26 98 290 paper field
# 27 106 35 paper field
# 28 111 198 paper field
# 29 119 62 paper field
# 30 119 86 paper field
# 31 119 300 paper field
# 32 119 382 paper field
# 33 121 62 paper field
# 34 121 86 paper field
# 35 121 250 paper field
# 36 130 214 paper field
# 37 133 189 paper field
# 38 133 290 paper field
# 39 140 15 paper field
# 40 147 498 paper field
# 41 150 298 paper field
# 42 153 67 paper field
# 43 154 186 paper field
# 44 159 261 paper field
# 45 159 329 paper field
# 46 171 121 paper field
# 47 171 373 paper field
# 48 177 397 paper field
# 49 184 62 paper field
# 50 184 86 paper field
# 51 184 300 paper field
# 52 184 329 paper field
# 53 184 382 paper field
# ...
# 316 316 316 paper paper
# 317 317 317 paper paper
# 318 318 318 paper paper
# 319 319 319 paper paper
# 320 320 320 paper paper
# 321 321 321 paper paper
# 322 322 322 paper paper
# 323 323 323 paper paper
# 324 324 324 paper paper
# 325 325 325 paper paper
# 326 326 326 paper paper
# 327 327 327 paper paper
# 328 328 328 paper paper
# 329 329 329 paper paper
# 330 330 330 paper paper
# 331 331 331 paper paper
# 332 332 332 paper paper
# 333 333 333 paper paper
# 334 334 334 paper paper
# 335 335 335 paper paper
# 336 336 336 paper paper
# 337 337 337 paper paper
# 338 338 338 paper paper
# 339 339 339 paper paper
# 340 340 340 paper paper
# 341 341 341 paper paper
# 342 342 342 paper paper
# 343 343 343 paper paper
# 344 344 344 paper paper
# 345 345 345 paper paper
# 346 346 346 paper paper
# 347 347 347 paper paper
# 348 348 348 paper paper
# 349 349 349 paper paper
# 350 350 350 paper paper
# 351 351 351 paper paper
# 352 352 352 paper paper
# 353 353 353 paper paper
# 354 354 354 paper paper
# 355 355 355 paper paper
# 356 356 356 paper paper
# 357 357 357 paper paper
# 358 358 358 paper paper
# 359 359 359 paper paper
# 360 360 360 paper paper
# 361 361 361 paper paper
# 362 362 362 paper paper
# 363 363 363 paper paper
# 364 364 364 paper paper
# 365 365 365 paper paper
# 366 366 366 paper paper
# 367 367 367 paper paper
# 368 368 368 paper paper
# 369 369 369 paper paper
# 370 370 370 paper paper
# 371 371 371 paper paper
# 372 372 372 paper paper
# 373 373 373 paper paper
# 374 374 374 paper paper
# 375 375 375 paper paper
# 376 376 376 paper paper
# 377 377 377 paper paper
# 378 378 378 paper paper
# 379 379 379 paper paper
# 380 380 380 paper paper
# 381 381 381 paper paper
# 382 382 382 paper paper
# 383 383 383 paper paper
# 384 384 384 paper paper
# 385 385 385 paper paper
# 386 386 386 paper paper
# 387 387 387 paper paper
# 388 388 388 paper paper
# 389 389 389 paper paper
# 390 390 390 paper paper
# 391 391 391 paper paper
# 392 392 392 paper paper
# 393 393 393 paper paper
# 394 394 394 paper paper
# 395 395 395 paper paper
# 396 396 396 paper paper
# 397 397 397 paper paper
# 398 398 398 paper paper
# 399 399 399 paper paper
# 400 400 400 paper paper
# 401 401 401 paper paper
# 402 402 402 paper paper
# 403 403 403 paper paper
# 404 404 404 paper paper
# 405 405 405 paper paper
# 406 406 406 paper paper
# 407 407 407 paper paper
# 408 408 408 paper paper
# 409 409 409 paper paper
# 410 410 410 paper paper
# 411 411 411 paper paper
# 412 412 412 paper paper
# 413 413 413 paper paper
# 414 414 414 paper paper
# 415 415 415 paper paper
# 416 416 416 paper paper
# 417 417 417 paper paper
# 418 418 418 paper paper
# 419 419 419 paper paper
# 420 420 420 paper paper
# 421 421 421 paper paper
# 422 422 422 paper paper
# 423 423 423 paper paper
# 424 424 424 paper paper
# 425 425 425 paper paper
# 426 426 426 paper paper
# 427 427 427 paper paper
# 428 428 428 paper paper
# 429 429 429 paper paper
# 430 430 430 paper paper
# 431 431 431 paper paper
# 432 432 432 paper paper
# 433 433 433 paper paper
# 434 434 434 paper paper
# 435 435 435 paper paper
# 436 436 436 paper paper
# 437 437 437 paper paper
# 438 438 438 paper paper
# 439 439 439 paper paper
# 440 440 440 paper paper
# 441 441 441 paper paper
# 442 442 442 paper paper
# 443 443 443 paper paper
# 444 444 444 paper paper
# 445 445 445 paper paper
# 446 446 446 paper paper
# 447 447 447 paper paper
# 448 448 448 paper paper
# 449 449 449 paper paper
# 450 450 450 paper paper
# 451 451 451 paper paper
# 452 452 452 paper paper
# 453 453 453 paper paper
# 454 454 454 paper paper
# 455 455 455 paper paper
# 456 456 456 paper paper
# 457 457 457 paper paper
# 458 458 458 paper paper
# 459 459 459 paper paper
# 460 460 460 paper paper
# 461 461 461 paper paper
# 462 462 462 paper paper
# 463 463 463 paper paper
# 464 464 464 paper paper
# 465 465 465 paper paper
# 466 466 466 paper paper
# 467 467 467 paper paper
# 468 468 468 paper paper
# 469 469 469 paper paper
# 470 470 470 paper paper
# 471 471 471 paper paper
# 472 472 472 paper paper
# 473 473 473 paper paper
# 474 474 474 paper paper
# 475 475 475 paper paper
# 476 476 476 paper paper
# 477 477 477 paper paper
# 478 478 478 paper paper
# 479 479 479 paper paper
# 480 480 480 paper paper
# 481 481 481 paper paper
# 482 482 482 paper paper
# 483 483 483 paper paper
# 484 484 484 paper paper
# 485 485 485 paper paper
# 486 486 486 paper paper
# 487 487 487 paper paper
# 488 488 488 paper paper
# 489 489 489 paper paper
# 490 490 490 paper paper
# 491 491 491 paper paper
# 492 492 492 paper paper
# 493 493 493 paper paper
# 494 494 494 paper paper
# 495 495 495 paper paper
# 496 496 496 paper paper
# 497 497 497 paper paper
# 498 498 498 paper paper
# 499 499 499 paper paper
# 500 500 500 paper paper
# 501 501 501 paper paper
# 502 502 502 paper paper
# 503 503 503 paper paper
# 504 504 504 paper paper
# 505 505 505 paper paper
# 506 506 506 paper paper
# 507 507 507 paper paper
# 508 508 508 paper paper
# 509 509 509 paper paper
# 510 510 510 paper paper
# 511 511 511 paper paper
# 512 512 512 paper paper
# 513 513 513 paper paper
# 514 514 514 paper paper
# 515 515 515 paper paper
# 516 516 516 paper paper
# 517 517 517 paper paper
# 518 518 518 paper paper
# 519 519 519 paper paper
# 520 520 520 paper paper
# 521 521 521 paper paper
# 522 522 522 paper paper
# 523 523 523 paper paper
# 524 524 524 paper paper
# 525 525 525 paper paper
# 526 526 526 paper paper
# 527 527 527 paper paper
# 528 528 528 paper paper
# 529 529 529 paper paper
# 530 530 530 paper paper
# 531 531 531 paper paper
# 532 532 532 paper paper
# 533 533 533 paper paper
# 534 534 534 paper paper
# 535 535 535 paper paper
# 536 536 536 paper paper
# 537 537 537 paper paper
# 538 538 538 paper paper
# 539 539 539 paper paper
# 540 540 540 paper paper
# 541 541 541 paper paper
# 542 542 542 paper paper
# 543 543 543 paper paper
# 544 544 544 paper paper
# 545 545 545 paper paper
# 546 546 546 paper paper
# 547 547 547 paper paper
# 548 548 548 paper paper
# 549 549 549 paper paper
# 550 550 550 paper paper
# 551 551 551 paper paper
# 552 552 552 paper paper
# 553 553 553 paper paper
# 554 554 554 paper paper
# 555 555 555 paper paper
# 556 556 556 paper paper
# 557 557 557 paper paper
# 558 558 558 paper paper
# 559 559 559 paper paper
# 560 560 560 paper paper
# 561 561 561 paper paper
# 562 562 562 paper paper
# 563 563 563 paper paper
# 564 564 564 paper paper
# 565 565 565 paper paper
# 566 566 566 paper paper
# 567 567 567 paper paper
# 568 568 568 paper paper
# 569 569 569 paper paper
# 570 570 570 paper paper
# 571 571 571 paper paper
# 572 572 572 paper paper
# 573 573 573 paper paper
# 574 574 574 paper paper
# 575 575 575 paper paper
# 576 576 576 paper paper
# 577 577 577 paper paper
# 578 578 578 paper paper
# 579 579 579 paper paper
# 580 580 580 paper paper
# 581 581 581 paper paper
# 582 582 582 paper paper
# 583 583 583 paper paper
# 584 584 584 paper paper
# 585 585 585 paper paper
# 586 586 586 paper paper
# 587 587 587 paper paper
# 588 588 588 paper paper
# 589 589 589 paper paper
# 590 590 590 paper paper
# 591 591 591 paper paper
# 592 592 592 paper paper
# 593 593 593 paper paper
# 594 594 594 paper paper
# 595 595 595 paper paper
# 596 596 596 paper paper
# 597 597 597 paper paper
# 598 598 598 paper paper
# 599 599 599 paper paper
# 0 12 406 paper paper
# 1 29 276 paper paper
# 2 33 104 paper paper
# 3 55 556 paper paper
# 4 68 246 paper paper
# 5 71 135 paper paper
# 6 79 100 paper paper
# 7 85 191 paper paper
# 8 101 26 paper paper
# 9 102 25 paper paper
# 10 102 202 paper paper
# 11 106 37 paper paper
# 12 106 213 paper paper
# 13 108 20 paper paper
# 14 109 85 paper paper
# 15 110 87 paper paper
# 16 111 72 paper paper
# 17 114 32 paper paper
# 18 115 35 paper paper
# 19 116 17 paper paper
# 20 117 37 paper paper
# 21 117 213 paper paper
# 22 117 377 paper paper
# 23 118 32 paper paper
# 24 118 114 paper paper
# 25 118 401 paper paper
# 26 120 10 paper paper
# 27 120 248 paper paper
# 28 120 385 paper paper
# 29 120 463 paper paper
# 30 120 530 paper paper
# 31 121 98 paper paper
# 32 122 4 paper paper
# 33 123 85 paper paper
# 34 123 307 paper paper
# 35 124 45 paper paper
# 36 124 111 paper paper
# 37 124 320 paper paper
# 38 126 50 paper paper
# 39 127 11 paper paper
# 40 127 227 paper paper
# 41 127 362 paper paper
# 42 127 485 paper paper
# 43 128 35 paper paper
# 44 128 210 paper paper
# 45 130 70 paper paper
# 46 131 472 paper paper
# 47 132 84 paper paper
# 48 133 64 paper paper
# 49 134 26 paper paper
# 50 136 95 paper paper
# 51 139 50 paper paper
# 52 140 12 paper paper
# 53 140 114 paper paper
# 54 140 236 paper paper
# 55 141 241 paper paper
# 56 141 303 paper paper
# 57 142 85 paper paper
# 58 142 191 paper paper
# 59 144 36 paper paper
# 60 145 7 paper paper
# 61 146 23 paper paper
# 62 149 56 paper paper
# 63 151 72 paper paper
# 64 152 23 paper paper
# 65 152 146 paper paper
# 66 153 79 paper paper
# 67 153 100 paper paper
# 68 154 66 paper paper
# 69 154 194 paper paper
# 70 154 290 paper paper
# 71 155 93 paper paper
# 72 155 517 paper paper
# 73 155 580 paper paper
# 74 157 93 paper paper
# 75 158 90 paper paper
# 76 159 32 paper paper
# 77 159 91 paper paper
# 78 159 418 paper paper
# 79 160 36 paper paper
# 80 161 21 paper paper
# 81 162 53 paper paper
# 82 163 86 paper paper
# 83 163 315 paper paper
# 84 164 47 paper paper
# 85 166 91 paper paper
# 86 166 175 paper paper
# 87 167 19 paper paper
# 88 168 17 paper paper
# 89 169 34 paper paper
# 90 171 2 paper paper
# 91 171 47 paper paper
# 92 172 34 paper paper
# 93 172 355 paper paper
# 94 172 528 paper paper
# 95 173 41 paper paper
# 96 175 91 paper paper
# 97 175 280 paper paper
# 98 176 271 paper paper
# 99 177 70 paper paper
# 100 178 53 paper paper
# 101 178 263 paper paper
# 102 179 82 paper paper
# 103 179 220 paper paper
# 104 179 268 paper paper
# 105 181 49 paper paper
# 106 182 6 paper paper
# 107 182 577 paper paper
# 108 183 46 paper paper
# 109 184 275 paper paper
# 110 184 443 paper paper
# 111 185 83 paper paper
# 112 186 78 paper paper
# 113 187 74 paper paper
# 114 188 28 paper paper
# 115 188 374 paper paper
# 116 189 14 paper paper
# 117 190 260 paper paper
# 118 192 44 paper paper
# 119 193 52 paper paper
# 120 194 66 paper paper
# 121 194 290 paper paper
# 122 195 265 paper paper
# 123 196 21 paper paper
# 124 198 31 paper paper
# 125 198 536 paper paper
# 126 199 30 paper paper
# 127 200 131 paper paper
# 128 200 194 paper paper
# 129 200 308 paper paper
# 130 200 480 paper paper
# 131 202 102 paper paper
# 132 203 331 paper paper
# 133 204 101 paper paper
# 134 205 141 paper paper
# 135 206 57 paper paper
# 136 207 112 paper paper
# 137 209 154 paper paper
# 138 209 194 paper paper
# 139 209 290 paper paper
# 140 210 35 paper paper
# 141 212 13 paper paper
# 142 212 454 paper paper
# 143 212 525 paper paper
# 144 214 150 paper paper
# 145 215 74 paper paper
# 146 215 344 paper paper
# 147 216 37 paper paper
# 148 216 106 paper paper
# 149 216 237 paper paper
# 150 216 291 paper paper
# 151 217 19 paper paper
# 152 217 167 paper paper
# 153 220 268 paper paper
# 154 222 110 paper paper
# 155 222 115 paper paper
# 156 223 5 paper paper
# 157 226 146 paper paper
# 158 226 152 paper paper
# 159 227 485 paper paper
# 160 228 439 paper paper
# 161 229 114 paper paper
# 162 229 118 paper paper
# 163 231 586 paper paper
# 164 232 0 paper paper
# 165 232 410 paper paper
# 166 234 52 paper paper
# 167 237 37 paper paper
# 168 237 213 paper paper
# 169 238 184 paper paper
# 170 238 302 paper paper
# 171 238 330 paper paper
# 172 240 33 paper paper
# 173 240 301 paper paper
# 174 242 90 paper paper
# 175 242 158 paper paper
# 176 242 587 paper paper
# 177 247 583 paper paper
# 178 248 530 paper paper
# 179 249 388 paper paper
# 180 251 489 paper paper
# 181 254 98 paper paper
# 182 254 367 paper paper
# 183 256 545 paper paper
# 184 258 54 paper paper
# 185 259 193 paper paper
# 186 263 53 paper paper
# 187 263 168 paper paper
# 188 263 337 paper paper
# 189 265 407 paper paper
# 190 270 343 paper paper
# 191 270 502 paper paper
# 192 274 185 paper paper
# 193 277 107 paper paper
# 194 278 381 paper paper
# 195 282 37 paper paper
# 196 282 106 paper paper
# 197 282 117 paper paper
# 198 282 213 paper paper
# 199 282 216 paper paper
# 200 282 237 paper paper
# 201 282 291 paper paper
# 202 282 377 paper paper
# 203 282 413 paper paper
# 204 283 267 paper paper
# 205 284 44 paper paper
# 206 286 88 paper paper
# 207 287 62 paper paper
# 208 288 103 paper paper
# 209 288 192 paper paper
# 210 289 149 paper paper
# 211 290 588 paper paper
# 212 291 37 paper paper
# 213 291 117 paper paper
# 214 291 213 paper paper
# 215 293 509 paper paper
# 216 294 45 paper paper
# 217 295 143 paper paper
# 218 296 164 paper paper
# 219 297 153 paper paper
# 220 297 478 paper paper
# 221 298 177 paper paper
# 222 298 399 paper paper
# 223 299 48 paper paper
# 224 301 489 paper paper
# 225 302 275 paper paper
# 226 302 330 paper paper
# 227 303 241 paper paper
# 228 305 115 paper paper
# 229 306 1 paper paper
# 230 311 317 paper paper
# 231 312 214 paper paper
# 232 313 590 paper paper
# 233 315 384 paper paper
# 234 318 87 paper paper
# 235 318 110 paper paper
# 236 318 558 paper paper
# 237 320 72 paper paper
# 238 320 111 paper paper
# 239 321 194 paper paper
# 240 321 209 paper paper
# 241 321 290 paper paper
# 242 322 143 paper paper
# 243 322 295 paper paper
# 244 322 411 paper paper
# 245 322 451 paper paper
# 246 323 311 paper paper
# 247 323 317 paper paper
# 248 324 32 paper paper
# 249 325 92 paper paper
# 250 328 90 paper paper
# 251 328 158 paper paper
# 252 328 242 paper paper
# 253 329 129 paper paper
# 254 330 275 paper paper
# 255 330 443 paper paper
# 256 332 297 paper paper
# 257 332 541 paper paper
# 258 334 14 paper paper
# 259 340 85 paper paper
# 260 340 109 paper paper
# 261 341 68 paper paper
# 262 341 246 paper paper
# 263 342 13 paper paper
# 264 346 7 paper paper
# 265 347 529 paper paper
# 266 348 28 paper paper
# 267 348 188 paper paper
# 268 348 374 paper paper
# 269 350 79 paper paper
# 270 352 104 paper paper
# 271 352 421 paper paper
# 272 353 4 paper paper
# 273 353 122 paper paper
# 274 354 219 paper paper
# 275 355 34 paper paper
# 276 355 528 paper paper
# 277 357 242 paper paper
# 278 357 422 paper paper
# 279 358 162 paper paper
# 280 359 85 paper paper
# 281 359 109 paper paper
# 282 359 142 paper paper
# 283 361 28 paper paper
# 284 361 374 paper paper
# 285 362 485 paper paper
# 286 366 533 paper paper
# 287 368 256 paper paper
# 288 370 264 paper paper
# 289 370 382 paper paper
# 290 370 548 paper paper
# 291 373 81 paper paper
# 292 378 132 paper paper
# 293 380 6 paper paper
# 294 380 182 paper paper
# 295 380 577 paper paper
# 296 383 42 paper paper
# 297 383 576 paper paper
# 301 388 292 paper paper
# 298 386 260 paper paper
# 299 387 181 paper paper
# 300 387 566 paper paper
# 302 389 190 paper paper
# 303 389 224 paper paper
# 304 389 544 paper paper
# 305 391 256 paper paper
# 306 391 545 paper paper
# 307 392 231 paper paper
# 308 394 420 paper paper
# 309 394 549 paper paper
# 310 396 198 paper paper
# 311 396 434 paper paper
# 312 397 409 paper paper
# 313 398 360 paper paper
# 314 400 535 paper paper
# 315 402 48 paper paper
# 316 402 148 paper paper
# 317 402 174 paper paper
# 318 402 299 paper paper
# 319 402 310 paper paper
# 320 402 442 paper paper
# 321 403 349 paper paper
# 322 404 30 paper paper
# 323 405 358 paper paper
# 324 410 192 paper paper
# 325 411 81 paper paper
# 326 411 373 paper paper
# 327 413 213 paper paper
# 328 413 237 paper paper
# 329 414 190 paper paper
# 330 415 31 paper paper
# 331 416 431 paper paper
# 332 418 594 paper paper
# 333 419 281 paper paper
# 334 420 52 paper paper
# 335 422 587 paper paper
# 336 423 272 paper paper
# 337 424 51 paper paper
# 338 425 203 paper paper
# 339 426 260 paper paper
# 340 427 393 paper paper
# 341 427 570 paper paper
# 342 429 106 paper paper
# 343 429 213 paper paper
# 344 429 216 paper paper
# 345 429 282 paper paper
# 346 429 413 paper paper
# 347 431 263 paper paper
# 348 431 337 paper paper
# 349 431 489 paper paper
# 350 432 193 paper paper
# 351 432 259 paper paper
# 352 434 198 paper paper
# 353 435 89 paper paper
# 354 436 123 paper paper
# 355 437 266 paper paper
# 356 438 386 paper paper
# 357 440 375 paper paper
# 358 445 135 paper paper
# 359 450 348 paper paper
# 360 450 361 paper paper
# 361 450 374 paper paper
# 362 451 41 paper paper
# 363 451 411 paper paper
# 364 454 342 paper paper
# 365 455 280 paper paper
# 366 456 273 paper paper
# 367 457 68 paper paper
# 368 457 123 paper paper
# 369 457 307 paper paper
# 370 457 500 paper paper
# 371 459 53 paper paper
# 372 459 301 paper paper
# 373 461 155 paper paper
# 374 461 492 paper paper
# 375 461 517 paper paper
# 376 462 357 paper paper
# 377 463 10 paper paper
# 378 463 530 paper paper
# 379 464 84 paper paper
# 380 466 156 paper paper
# 381 469 89 paper paper
# 382 471 392 paper paper
# 383 471 563 paper paper
# 384 474 104 paper paper
# 385 474 421 paper paper
# 386 475 38 paper paper
# 387 475 173 paper paper
# 388 475 338 paper paper
# 389 475 451 paper paper
# 390 476 327 paper paper
# 391 476 390 paper paper
# 392 478 153 paper paper

# %%
train_data = [job.get() for job in jobs[:-2]]
valid_data = [jobs[-2].get(), jobs[-1].get()]
pool.close()
pool.join()

# %%
data, paper_ids, texts = train_data[0]

# %%
node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict = data

# %%
node_dict
# Out:
# {'paper': [0, 0],
#  'venue': [510, 1],
#  'field': [689, 2],
#  'author': [1189, 3],
#  'affiliation': [1689, 4]}

# %%
edge_index[1][edge_index[0] == paper_ids[4]]
# Out:
# tensor([402,  78, 147, 319, 398,   7, 564, 689, 689])

# %%
graph.edge_list.keys()
# Out:
# dict_keys(['venue', 'paper', 'field', 'affiliation', 'author'])

# %%
node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict = data
reps = gnn(node_feature.to(device), node_type.to(device), edge_time.to(device), \
           edge_index.to(device), edge_type.to(device))[node_dict['paper'][0] + paper_ids]

# %%
for epoch in np.arange(epoch_num * 100)+1:
    train_data = [job.get() for job in jobs[:-2]]
    valid_data = [jobs[-2].get(), jobs[-1].get()]
    pool.close()
    pool.join()
    pool = mp.Pool(8)
    jobs = prepare_data(pool, process_ids)
    et = time.time()
    print('Data Preparation: %.1fs' % (et - st))
    
    train_losses = []
    gnn.train()
    rnn.train()
    torch.cuda.empty_cache()
    for data, paper_ids, texts in train_data:
        node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict = data
        reps = gnn(node_feature.to(device), node_type.to(device), edge_time.to(device), \
                   edge_index.to(device), edge_type.to(device))[node_dict['paper'][0] + paper_ids]
        inp_idxs, out_idxs, masks, lens = parse_text(texts, w2v_model, device)
        pred_prob = rnn(inp_idxs, reps.repeat(inp_idxs.shape[0], 1, 1))
        loss = criterion(pred_prob[masks], out_idxs[masks]).mean()

        optimizer.zero_grad() 
        loss.backward()
        torch.nn.utils.clip_grad_norm_(rnn.parameters(), 0.2)
        optimizer.step()
        train_losses += [loss.cpu().detach().tolist()]
        train_step += 1
        scheduler.step(train_step)
        del loss, pred_prob
        torch.cuda.empty_cache()
    '''
        Valid
    '''
    gnn.eval()
    rnn.eval()
    with torch.no_grad():
        valid_accs   = []
        valid_losses = []
        for data, paper_ids, texts in valid_data:
            node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict = data
            reps = gnn(node_feature.to(device), node_type.to(device), edge_time.to(device), \
                       edge_index.to(device), edge_type.to(device))[node_dict['paper'][0] + paper_ids]
            inp_idxs, out_idxs, masks, lens = parse_text(texts, w2v_model, device)
            pred_prob = rnn(inp_idxs, reps.repeat(inp_idxs.shape[0], 1, 1))
            loss = criterion(pred_prob[masks], out_idxs[masks])
            valid_loss = loss.cpu().detach().tolist()
            
            if epoch % 100 == 0:
                l_s = []
                s = 0
                for i in lens:
                    l_s += [np.average(valid_losses[s: s+i])]
                    s = s+i
                predict_sent = []
                label_sent   = []
                for s, text in zip(pred_prob.transpose(0,1).argmax(dim=-1), texts):
                    sent = []
                    for w in s:
                        word = w2v_model.wv.index2word[w]
                        sent += [w2v_model.wv.index2word[w]]
                        if word == '<eos>':
                            break
                    label_sent += [text]
                    predict_sent += [' '.join(sent)]

                for i in np.argsort(l_s):
                    print('Loss: %.4f' % l_s[i])
                    print('Predict: %s' % predict_sent[i])
                    print('Label: %s' % label_sent[i])
    
            valid_losses += [np.average(valid_loss)]
            del loss, pred_prob
        st = time.time()
        print(("Epoch: %d (%.1fs)  LR: %.5f Train Loss: %f  Valid Loss: %f") % \
              (epoch, (st-et), optimizer.param_groups[0]['lr'], np.average(train_losses), \
               np.average(valid_losses)))
        if np.average(valid_losses) < best_val:
            best_val = np.average(valid_losses)
            torch.save(rnn, './save/rnn.pt')
            torch.save(gnn, './save/gen_gnn.pt')
        stats += [[train_losses, valid_losses]]

# %%
losses = []
for epoch, (train_losses, valid_losses) in enumerate(stats):
    for ti in train_losses:
        losses += [[ti, 'Train', epoch]]
    for ti in valid_losses:
        losses += [[ti, 'Valid', epoch]]
sb.lineplot(data = pd.DataFrame(losses, columns=['loss', 'Type', 'Epoch']), x = 'Epoch', y='loss', hue='Type')
plt.show()

# %%
loss

# %%
valid_accs   = []
valid_losses = []
for data, paper_ids, texts in valid_data:
    node_feature, node_type, edge_time, edge_index, edge_type, node_dict, edge_dict = data
    reps = gnn(node_feature.to(device), node_type.to(device), edge_time.to(device), \
               edge_index.to(device), edge_type.to(device))[node_dict['paper'][0] + paper_ids]
    inp_idxs, out_idxs, masks, lens = parse_text(texts, w2v_model, device)
    pred_prob = rnn(inp_idxs, reps.repeat(inp_idxs.shape[0], 1, 1))
    loss = criterion(pred_prob[masks], out_idxs[masks])
    valid_loss = loss.cpu().detach().tolist()

    l_s = []
    s = 0
    for i in lens:
        l_s += [np.average(valid_loss[s: s+i])]
        s = s+i
    predict_sent = []
    label_sent   = []
    for s, text in zip(pred_prob.transpose(0,1).argmax(dim=-1), texts):
        sent = []
        for w in s:
            word = w2v_model.wv.index2word[w]
            sent += [w2v_model.wv.index2word[w]]
            if word == '<eos>':
                break
        label_sent += [text]
        predict_sent += [' '.join(sent)]

    for i in np.argsort(l_s):
        print('Loss: %.4f' % l_s[i])
        print('Predict: %s' % predict_sent[i])
        print('Label: %s' % label_sent[i])

    valid_losses += [np.average(valid_loss)]

# %%
ban   = defaultdict( #target_type
                        lambda: defaultdict(lambda: -100) # {target_id}
                    )

# %%
ban['paper'][123] = 0

# %%
ban['paper'][456]
